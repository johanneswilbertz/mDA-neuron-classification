# %% [markdown]
# ## Machine learning notebook
# This notebook performs data loading, outlier removal and data normalization and executes SVM, LightGBM and LDA algorithms. This version of the notebook has been optimized for the raw data set 4 in RawData_4.csv.

# %% [markdown]
# ### Load required packages

# %%
import plotly.io as pio
import plotly.graph_objects as go
import plotly.express as px
import ipywidgets as widgets
from ipywidgets import HBox,VBox
import plotly.figure_factory as ff
import plotly.offline as plt_off
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import os
import sklearn.cluster as cluster
from collections import defaultdict
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.svm import SVC
from sklearn.svm import LinearSVC
from statannot import add_stat_annotation
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.preprocessing import LabelEncoder
import lightgbm as lgb
from sklearn.model_selection import StratifiedShuffleSplit

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Define data paths and load as dataframe

# %%
# Input directory
dbs=[r'L:\\PD\\Experiment\\Stability_LRRK2\\RawData_4.csv']

print(dbs[0])

training_plate = 'p3'
testing_plates = ['p1', 'p2']

# Output directory
output_path = 'B:\\Project - PD\\LRRK2 paper\\Figures\\RawData_4\\Across-plate-validation\\'

if not os.path.exists(output_path):
    os.makedirs(output_path, exist_ok=True)
    
main_df_tot = pd.read_csv(dbs[0])
main_df_tot.dropna(inplace=True)

main_df_classif_training = main_df_tot[main_df_tot.Plate==training_plate]
main_df_classif_testing = main_df_tot[(main_df_tot.Plate==testing_plates[0]) | (main_df_tot.Plate==testing_plates[1])]

print('Plate ', training_plate, ' :')
display(main_df_classif_training.tags.value_counts())

print('Plate Testing :')
display(main_df_classif_testing.tags.value_counts())
# Out:
# L:\\PD\\Experiment\\Stability_LRRK2\\RawData_4.csv
# Plate  p3  :
# Mut;DMSO          126
# WT;DMSO            85
# PEP005;WT           6
# Mut;Prostratin      6
# Mut;PEP005          6
# Prostratin;WT       5
# Name: tags, dtype: int64
# Plate Testing :
# Mut;DMSO          266
# WT;DMSO           169
# PEP005;WT          12
# Mut;Prostratin     12
# Mut;PEP005         12
# Prostratin;WT      11
# Name: tags, dtype: int64

# %% [markdown]
# ### Specify data tags/classes
# Used genotypes (i.e. Mutant, WT) and treatment condition (i.e. DMSO, compound X) are specified here.

# %%
whole_df_training = main_df_classif_training.copy()

main_df_training = main_df_classif_training.set_index(['Plate', 'Well'])
main_df_testing = main_df_classif_testing.set_index(['Plate', 'Well'])

ctrl_pos = 'WT;DMSO'
ctrl_neg = 'Mut;DMSO'

remove_corr = False

# Define order for plotting
# order = [ctrl_pos, 'PEP005;WT', 'Prostratin;WT', ctrl_neg, 'Mut;PEP005', 'Mut;Prostratin']
order = [ctrl_pos, ctrl_neg, 'WT;DMSO_p1', 'Mut;DMSO_p1', 'WT;DMSO_p2', 'Mut;DMSO_p2']

# Define pairs for statisitical tests shown in swarm-boxplots
box_pairs = [(ctrl_neg, ctrl_pos), (ctrl_pos, 'WT;DMSO_p1'), (ctrl_pos, 'WT;DMSO_p2'),
             (ctrl_neg, 'Mut;DMSO_p1'), (ctrl_neg, 'Mut;DMSO_p2')]

# %% [markdown]
# ### Define Functions : Outliers removing and Normalization
# Outlier removal possible with different methods (mean +- N sigmas or median +- inter-quartiles distance) & Normalization possible with different methods (standardization, quantiles based standardization, by mean, min-max)

# %%
def remove_outliers_by_plate(df_in, sigma, method, neg, pos):

    print('[DATA BEFORE OUTLIERS:]', len(df_in))

    list_df_plate = []

    df_in['Plate2'] = df_in.index.get_level_values('Plate')

    for plate in np.unique(df_in['Plate2']):

        df_plate = pd.DataFrame(df_in[df_in['Plate2'] == plate])

        data_neg = df_plate[df_plate['tags'] == neg]
        data_pos = df_plate[df_plate['tags'] == pos]
        data_cpd = df_plate[~((df_plate['tags'] == neg) | (df_plate['tags'] == pos))]

        print('CPDS LEN = ', len(data_cpd))

        data_neg = data_neg.drop(['Plate2', 'tags'], axis=1, errors='ignore')
        data_pos = data_pos.drop(['Plate2', 'tags'], axis=1, errors='ignore')
        data_cpd = data_cpd.drop(['Plate2'], axis=1, errors='ignore')

        data_neg = data_neg.astype(np.float64)
        data_pos = data_pos.astype(np.float64)

        if method == 'std':
            data_neg = data_neg[np.abs(data_neg - data_neg.mean()) / data_neg.std() <= sigma].dropna()
            data_pos = data_pos[np.abs(data_pos - data_pos.mean()) / data_pos.std() <= sigma].dropna()

        elif method == 'med_abs_dev':
            data_neg = data_neg[np.abs(data_neg - data_neg.median()) <= sigma * data_neg.mad()].dropna()
            data_pos = data_pos[np.abs(data_pos - data_pos.median()) <= sigma * data_pos.mad()].dropna()

        data_neg['tags'] = neg
        data_pos['tags'] = pos

        df = pd.concat([data_neg, data_pos, data_cpd])
        list_df_plate.append(df)

    df_concat = pd.concat(list_df_plate)

    print('[DATA AFTER OUTLIERS:]', df_concat.shape[0])

    return df_concat

def norm_centered_by_plate(df, norm_type, neg, pos):

    df['Plate2'] = df.index.get_level_values('Plate')

    list_df_group = []

    for plate in np.unique(df['Plate2']):

        df_plate = df[df['Plate2'] == plate]

        neg_group = pd.DataFrame(df_plate[df_plate['tags'] == neg])
        pos_group = pd.DataFrame(df_plate[df_plate['tags'] == pos])

        for column in df_plate:
            if column != 'Plate2' and column != 'tags':

                mean_neg = np.mean(neg_group[column])
                mean_pos = np.mean(pos_group[column])
                median_neg = np.median(neg_group[column])

                std_neg = np.std(neg_group[column])
                std_pos = np.std(pos_group[column])

                min_neg = np.min(neg_group[column])
                max_neg = np.max(neg_group[column])

                min_pos = np.min(pos_group[column])
                max_pos = np.max(pos_group[column])

                min_5sigma_neg = 0.
                min_5sigma_pos = 0.
                max_5sigma_neg = 0.
                max_5sigma_pos = 0.

                if norm_type == 'std':
                    if std_neg == 0:
                        std_neg = 1.

                    print(column, median_neg, std_neg)

                    df_plate[column] = (df_plate[column] - median_neg) / std_neg

                if norm_type == 'med_abs_dev':
                    if diff_quartile_neg == 0:
                        diff_quartile_neg = 1.

                    print(column, median_neg, diff_quartile_neg)

                    df_plate[column] = (df_plate[column] - median_neg) / df_plate[column].mad()

                if norm_type == 'mean':
                    if mean_neg == 0:
                        mean_neg = 1
                    df_plate[column] = df_plate[column] / mean_neg

                if norm_type == 'min_max':

                    sigma = 5

                    if mean_neg < mean_pos:
                        min_5sigma_neg = mean_neg - sigma * std_neg
                        max_5sigma_pos = mean_pos + sigma * std_pos

                        if min_5sigma_neg > min_neg:
                            min_neg = min_5sigma_neg

                        if max_5sigma_pos < max_pos:
                            max_pos = max_5sigma_pos

                    if mean_pos < mean_neg:
                        min_5sigma_pos = mean_pos - sigma * std_pos
                        max_5sigma_neg = mean_neg + sigma * std_neg

                        if min_5sigma_pos > min_pos:
                            min_pos = min_5sigma_pos

                        if max_5sigma_neg < max_neg:
                            max_neg = max_5sigma_neg

                    df_plate[column] -= min_neg

                    if (max_neg - min_neg) != 0:
                        df_plate[column] /= (max_neg - min_neg)
                    else:
                        df_plate[column] /= 1.

        list_df_group.append(df_plate)

    normalized_df = pd.concat(list_df_group)
    normalized_df.drop('Plate2', axis=1, inplace=True)

    print('[DATA NORMALIZED]')

    return normalized_df

# %% [markdown]
# ### Data pre-processing (outlier removal & normalization)
# All input image features and statisitical thresholds for outlier removal and normalization are listed. Some image features could not be calculated or were deemed irrelevant and where excluded (commented out).

# %%
# All image features to be used
selected_features = ['Cell_Correlation_MAP2_SNCA', 
            'Cell_Correlation_TH_SNCA', 
            'Cell_Correlation_VanSteelselsMeanX_TH_SNCA', 
            'Cell_Correlation_VanSteelselsMeanY_TH_SNCA', 
            'Cell_Correlation_VanSteelselsSigmaX_TH_SNCA', 
            'Cell_Correlation_VanSteelselsSigmaY_TH_SNCA', 
            'Cell_Intensity_MeanIntensity_MAP2', 
            'Cell_Intensity_MeanIntensity_SNCA', 
            'Cell_Intensity_MeanIntensity_TH', 
            'Cell_Intensity_SumIntensityPerNuclei_SNCA', 
            'Cell_MAP2_SNCA_Intensity_MeanIntensity_SNCA', 
            'Cell_Neurites_BranchingPointsPerNuclei_MAP2', 
            'Cell_Neurites_BranchingPointsPerNuclei_TH', 
            'Cell_Neurites_LengthPerNuclei_MAP2', 
            'Cell_Neurites_LengthPerNuclei_TH', 
            'Cell_Neurites_Length_MAP2', 
            'Cell_Neurites_Length_TH',
            'Cell_SurfacePerNuclei_MAP2', 
            'Cell_SurfacePerNuclei_MAP2_SNCA', 
            'Cell_SurfacePerNuclei_SNCA', 
            'Cell_SurfacePerNuclei_TH', 
            'Cell_SurfacePerNuclei_TH_SNCA', 
            'Cell_Surface_RatioSurface_TH_SNCA', 
            # 'Cell_Surface_TotalSurface_MAP2', 
            # 'Cell_Surface_TotalSurface_SNCA', 
            # 'Cell_Surface_TotalSurface_SNCA_MAP2', 
            # 'Cell_Surface_TotalSurface_TH', 
            # 'Cell_Surface_TotalSurface_TH_SNCA',
            'Cell_TH_SNCA_Intensity_MeanIntensity_SNCA', 
            'Cell_TH_SNCA_Intensity_MeanIntensity_TH', 
            'Cell_TH_SNCA_Intensity_SumIntensityPerNuclei_SNCA', 
            'Cell_Texture_SNCA_AngularSecondMoment_000', 
            'Cell_Texture_SNCA_AngularSecondMoment_045', 
            'Cell_Texture_SNCA_AngularSecondMoment_090', 
            'Cell_Texture_SNCA_AngularSecondMoment_135', 
            'Cell_Texture_SNCA_Contrast_000', 
            'Cell_Texture_SNCA_Contrast_045', 
            'Cell_Texture_SNCA_Contrast_090', 
            'Cell_Texture_SNCA_Contrast_135', 
            'Cell_Texture_SNCA_Correlation_000', 
            'Cell_Texture_SNCA_Correlation_045', 
            'Cell_Texture_SNCA_Correlation_090', 
            'Cell_Texture_SNCA_Correlation_135', 
            'Cell_Texture_SNCA_DifferenceEntropy_000', 
            'Cell_Texture_SNCA_DifferenceEntropy_045', 
            'Cell_Texture_SNCA_DifferenceEntropy_090', 
            'Cell_Texture_SNCA_DifferenceEntropy_135', 
            'Cell_Texture_SNCA_DifferenceVariance_000', 
            'Cell_Texture_SNCA_DifferenceVariance_045', 
            'Cell_Texture_SNCA_DifferenceVariance_090', 
            'Cell_Texture_SNCA_DifferenceVariance_135', 
            'Cell_Texture_SNCA_Entropy_000', 
            'Cell_Texture_SNCA_Entropy_045', 
            'Cell_Texture_SNCA_Entropy_090', 
            'Cell_Texture_SNCA_Entropy_135', 
            'Cell_Texture_SNCA_InfoMeasuresOfCorr1_000', 
            'Cell_Texture_SNCA_InfoMeasuresOfCorr1_045', 
            'Cell_Texture_SNCA_InfoMeasuresOfCorr1_090', 
            'Cell_Texture_SNCA_InfoMeasuresOfCorr1_135', 
            'Cell_Texture_SNCA_InfoMeasuresOfCorr2_000', 
            'Cell_Texture_SNCA_InfoMeasuresOfCorr2_045', 
            'Cell_Texture_SNCA_InfoMeasuresOfCorr2_090', 
            'Cell_Texture_SNCA_InfoMeasuresOfCorr2_135', 
            'Cell_Texture_SNCA_InverseDiffMoment_000', 
            'Cell_Texture_SNCA_InverseDiffMoment_045', 
            'Cell_Texture_SNCA_InverseDiffMoment_090', 
            'Cell_Texture_SNCA_InverseDiffMoment_135', 
            'Cell_Texture_SNCA_SumAverage_000', 
            'Cell_Texture_SNCA_SumAverage_045', 
            'Cell_Texture_SNCA_SumAverage_090', 
            'Cell_Texture_SNCA_SumAverage_135', 
            'Cell_Texture_SNCA_SumEntropy_000', 
            'Cell_Texture_SNCA_SumEntropy_045', 
            'Cell_Texture_SNCA_SumEntropy_090', 
            'Cell_Texture_SNCA_SumEntropy_135', 
            'Cell_Texture_SNCA_SumOfSquares_000', 
            'Cell_Texture_SNCA_SumOfSquares_045', 
            'Cell_Texture_SNCA_SumOfSquares_090', 
            'Cell_Texture_SNCA_SumOfSquares_135', 
            'Cell_Texture_SNCA_SumVariance_000', 
            'Cell_Texture_SNCA_SumVariance_045', 
            'Cell_Texture_SNCA_SumVariance_090', 
            'Cell_Texture_SNCA_SumVariance_135', 
            'Cytoplasm_Intensity_MeanIntensity_SNCA', 
            'Cytoplasm_MAP2_SNCA_Intensity_MeanIntensity_SNCA', 
            'Cytoplasm_SurfacePerNuclei_SNCA', 
            'Cytoplasm_SurfacePerNuclei_TH_SNCA', 
            'Cytoplasm_Surface_TotalSurface_SNCA', 
            'IndividualCell_Intensity_MeanIntensity_SNCA', 
            'IndividualCell_Intensity_RadialProfile_InterceptFit_SNCA',
            'IndividualCell_Intensity_RadialProfile_MaxSlope_SNCA', 
            'IndividualCell_Intensity_RadialProfile_Maximum_SNCA', 
            'IndividualCell_Intensity_RadialProfile_MeanCoeffVar_SNCA', 
            'IndividualCell_Intensity_RadialProfile_MeanGradient_SNCA', 
            'IndividualCell_Intensity_RadialProfile_Mean_SNCA', 
            'IndividualCell_Intensity_RadialProfile_Median_SNCA', 
            #'IndividualCell_Intensity_RadialProfile_Minimum_SNCA', 
            'IndividualCell_Intensity_RadialProfile_Q1_SNCA', 
            'IndividualCell_Intensity_RadialProfile_Q3_SNCA', 
            'IndividualCell_Intensity_RadialProfile_SlopeFit_SNCA', 
            'IndividualCell_Intensity_RadialProfile_StdCoeffVar_SNCA', 
            'IndividualCell_Intensity_RadialProfile_Std_SNCA', 
            'IndividualCell_Intensity_SumIntensity_SNCA', 
            'IndividualCell_Surface_MeanSurface_SNCA', 
            'Membrane_Intensity_MeanIntensity_MAP2', 
            'Membrane_Intensity_MeanIntensity_SNCA', 
            'Membrane_Intensity_MeanIntensity_TH', 
            'Membrane_Surface_SurfacePerNuclei_MAP2', 
            'Membrane_Surface_SurfacePerNuclei_SNCA', 
            'Membrane_Surface_SurfacePerNuclei_TH', 
            'Nuclei_Living_Ratio_MAP2', 
            'Nuclei_Living_Ratio_MAP2_SNCA', 
            #'Nuclei_Living_Ratio_SNCA', 
            'Nuclei_Living_Ratio_TH_SNCA', 
            # 'Nuclei_Number_Dead', 
            # 'Nuclei_Number_Living', 
            # 'Nuclei_Number_MAP2', 
            # 'Nuclei_Number_MAP2_SNCA', 
            # 'Nuclei_Number_SNCA', 
            # 'Nuclei_Number_TH', 
            # 'Nuclei_Number_TH_SNCA', 
            # 'Nuclei_Ratio_Dead', 
            # 'Nuclei_Ratio_Living', 
            'Nuclei_Surface_MeanArea',
            "tags"]

method_outliers  = 'std' # Outlier method: 'std' or 'std_quartiles'
outliers_sigma = 2.5 # Number of sigmas used for outlier removal

main_training = main_df_training[selected_features]
main_testing = main_df_testing[selected_features]

display(main_training.tags.value_counts())

main_df_training_wo_outliers = pd.DataFrame()

main_df_training_wo_outliers = remove_outliers_by_plate(main_training, outliers_sigma, 'std', ctrl_neg, ctrl_pos)
main_df_training_normed = norm_centered_by_plate(main_df_training_wo_outliers, 'std', ctrl_neg, ctrl_pos)

X_all_cpds_training = main_df_training_normed[selected_features[:-1]]
Y_all_cpds_training = main_df_training_normed['tags']

# Value counts per class after outlier removal and normalization
display(main_df_training_normed.tags.value_counts())

df_training_normed_ctrls = main_df_training_normed[main_df_training_normed.tags.isin([ctrl_neg, ctrl_pos])]

X_training = df_training_normed_ctrls[selected_features[:-1]]
Y_training = df_training_normed_ctrls['tags']

whole_x_training = main_df_training_normed[selected_features[:-1]]
whole_y_training = main_df_training_normed['tags']

df_testing_ctrls = main_df_classif_testing[main_df_classif_testing.tags.isin([ctrl_neg, ctrl_pos])]
print(df_testing_ctrls.tags.value_counts())
# Out:
# Mut;DMSO          126
# WT;DMSO            85
# PEP005;WT           6
# Mut;Prostratin      6
# Mut;PEP005          6
# Prostratin;WT       5
# Name: tags, dtype: int64
# [DATA BEFORE OUTLIERS:] 234
# CPDS LEN =  23
# [DATA AFTER OUTLIERS:] 150
# Cell_Correlation_MAP2_SNCA 0.2720235 0.0616968485456594
# Cell_Correlation_TH_SNCA 0.06448670000000001 0.0357302868894038
# Cell_Correlation_VanSteelselsMeanX_TH_SNCA 25.43075 4.904399860999912
# Cell_Correlation_VanSteelselsMeanY_TH_SNCA 24.5108 4.219080927656438
# Cell_Correlation_VanSteelselsSigmaX_TH_SNCA 4.002105 2.9739808846745412
# Cell_Correlation_VanSteelselsSigmaY_TH_SNCA 3.9247050000000003 2.8251556626745975
# Cell_Intensity_MeanIntensity_MAP2 638.5889999999999 36.15784164027593
# Cell_Intensity_MeanIntensity_SNCA 708.8620000000001 55.28192008020196
# Cell_Intensity_MeanIntensity_TH 437.045 75.82325547893382
# Cell_Intensity_SumIntensityPerNuclei_SNCA 1314710.0 169146.60102872932
# Cell_MAP2_SNCA_Intensity_MeanIntensity_SNCA 782.7415000000001 113.23969138935175
# Cell_Neurites_BranchingPointsPerNuclei_MAP2 2.07768 0.3643549658483458
# Cell_Neurites_BranchingPointsPerNuclei_TH 1.65762 0.28108756568338555
# Cell_Neurites_LengthPerNuclei_MAP2 293.37 38.48800684415402
# Cell_Neurites_LengthPerNuclei_TH 234.6325 39.807646967924384
# Cell_Neurites_Length_MAP2 108128.5 19774.79153771581
# Cell_Neurites_Length_TH 107740.5 19477.811373193355
# Cell_SurfacePerNuclei_MAP2 4627.84 430.7558080808639
# Cell_SurfacePerNuclei_MAP2_SNCA 1721.785 158.72336867158015
# Cell_SurfacePerNuclei_SNCA 1810.1950000000002 164.5113654249487
# Cell_SurfacePerNuclei_TH 4784.725 355.2278782633356
# Cell_SurfacePerNuclei_TH_SNCA 1779.835 153.6025514137168
# Cell_Surface_RatioSurface_TH_SNCA 0.6607465 0.11695546846125417
# Cell_TH_SNCA_Intensity_MeanIntensity_SNCA 749.8845 121.86917439455281
# Cell_TH_SNCA_Intensity_MeanIntensity_TH 346.8265 61.70114645080791
# Cell_TH_SNCA_Intensity_SumIntensityPerNuclei_SNCA 1389000.0 266515.5143888143
# Cell_Texture_SNCA_AngularSecondMoment_000 0.8703259999999999 0.02837132769938443
# Cell_Texture_SNCA_AngularSecondMoment_045 0.865581 0.02901929270076426
# Cell_Texture_SNCA_AngularSecondMoment_090 0.8704195 0.028347951453502197
# Cell_Texture_SNCA_AngularSecondMoment_135 0.86539 0.029052671501021008
# Cell_Texture_SNCA_Contrast_000 0.754896 1.4314810913162779
# Cell_Texture_SNCA_Contrast_045 1.051515 1.8470080503181057
# Cell_Texture_SNCA_Contrast_090 0.6231905 1.4236958271078086
# Cell_Texture_SNCA_Contrast_135 0.996695 1.8568381816101829
# Cell_Texture_SNCA_Correlation_000 443.707 919.0987986618949
# Cell_Texture_SNCA_Correlation_045 402.899 874.6824950734972
# Cell_Texture_SNCA_Correlation_090 448.98 920.3531504201245
# Cell_Texture_SNCA_Correlation_135 397.73850000000004 874.2523659472995
# Cell_Texture_SNCA_DifferenceEntropy_000 0.07651175 0.014210217346750348
# Cell_Texture_SNCA_DifferenceEntropy_045 0.08797315 0.015764542095321292
# Cell_Texture_SNCA_DifferenceEntropy_090 0.0761638 0.014199098068204586
# Cell_Texture_SNCA_DifferenceEntropy_135 0.0878158 0.01583016845123275
# Cell_Texture_SNCA_DifferenceVariance_000 9.849999999999999e-07 5.503869221387429e-07
# Cell_Texture_SNCA_DifferenceVariance_045 1.245e-06 6.571829881489209e-07
# Cell_Texture_SNCA_DifferenceVariance_090 9.975000000000002e-07 5.508542724810181e-07
# Cell_Texture_SNCA_DifferenceVariance_135 1.235e-06 6.630698208258258e-07
# Cell_Texture_SNCA_Entropy_000 0.1735565 0.03263750271643893
# Cell_Texture_SNCA_Entropy_045 0.180089 0.03381406095362539
# Cell_Texture_SNCA_Entropy_090 0.1736335 0.03259545186684988
# Cell_Texture_SNCA_Entropy_135 0.18079800000000001 0.03386681255167835
# Cell_Texture_SNCA_InfoMeasuresOfCorr1_000 -0.512049 0.023860086831066045
# Cell_Texture_SNCA_InfoMeasuresOfCorr1_045 -0.4463055 0.022319125845639953
# Cell_Texture_SNCA_InfoMeasuresOfCorr1_090 -0.5131619999999999 0.024391574206615783
# Cell_Texture_SNCA_InfoMeasuresOfCorr1_135 -0.4457195 0.022603205352960145
# Cell_Texture_SNCA_InfoMeasuresOfCorr2_000 0.3382175 0.028118214295171674
# Cell_Texture_SNCA_InfoMeasuresOfCorr2_045 0.3176145 0.027013166967386953
# Cell_Texture_SNCA_InfoMeasuresOfCorr2_090 0.3398195 0.028241415236254837
# Cell_Texture_SNCA_InfoMeasuresOfCorr2_135 0.31619600000000003 0.026930890552699295
# Cell_Texture_SNCA_InverseDiffMoment_000 0.974449 0.010974623303210468
# Cell_Texture_SNCA_InverseDiffMoment_045 0.9698495 0.012418452585280345
# Cell_Texture_SNCA_InverseDiffMoment_090 0.974253 0.010975355855499974
# Cell_Texture_SNCA_InverseDiffMoment_135 0.970009 0.01238970303351802
# Cell_Texture_SNCA_SumAverage_000 0.24290499999999998 0.42258670897202893
# Cell_Texture_SNCA_SumAverage_045 0.2429325 0.4226194207553206
# Cell_Texture_SNCA_SumAverage_090 0.24294300000000002 0.42255110281469016
# Cell_Texture_SNCA_SumAverage_135 0.2429325 0.4226191982076599
# Cell_Texture_SNCA_SumEntropy_000 0.158092 0.029434375014678802
# Cell_Texture_SNCA_SumEntropy_045 0.162245 0.029984271032823123
# Cell_Texture_SNCA_SumEntropy_090 0.1578735 0.02941706115389928
# Cell_Texture_SNCA_SumEntropy_135 0.1623235 0.03000345408985965
# Cell_Texture_SNCA_SumOfSquares_000 1.85888 3.62691602647758
# Cell_Texture_SNCA_SumOfSquares_045 1.86024 3.6276458598503876
# Cell_Texture_SNCA_SumOfSquares_090 1.85906 3.6266305644752688
# Cell_Texture_SNCA_SumOfSquares_135 1.86024 3.6276445062415252
# Cell_Texture_SNCA_SumVariance_000 6.811014999999999 13.432190495482452
# Cell_Texture_SNCA_SumVariance_045 6.56316 13.125569696011741
# Cell_Texture_SNCA_SumVariance_090 6.8695699999999995 13.441506313784236
# Cell_Texture_SNCA_SumVariance_135 6.586105 13.121271824033059
# Cytoplasm_Intensity_MeanIntensity_SNCA 708.1759999999999 291.89344066660215
# Cytoplasm_MAP2_SNCA_Intensity_MeanIntensity_SNCA 765.082 648.1779218913734
# Cytoplasm_SurfacePerNuclei_SNCA 305.501 64.11844047826398
# Cytoplasm_SurfacePerNuclei_TH_SNCA 327.952 66.06073077951552
# Cytoplasm_Surface_TotalSurface_SNCA 234745.0 57365.574045641784
# IndividualCell_Intensity_MeanIntensity_SNCA 688.734 53.0539639809733
# IndividualCell_Intensity_RadialProfile_InterceptFit_SNCA 830.9745 98.50770243416649
# IndividualCell_Intensity_RadialProfile_MaxSlope_SNCA -5.787050000000001 2.907011137374013
# IndividualCell_Intensity_RadialProfile_Maximum_SNCA 1592.47 231.94810528780647
# IndividualCell_Intensity_RadialProfile_MeanCoeffVar_SNCA 29.87765 6.148316936442966
# IndividualCell_Intensity_RadialProfile_MeanGradient_SNCA -4.869275 2.3523510612302077
# IndividualCell_Intensity_RadialProfile_Mean_SNCA 864.8240000000001 89.706176105334
# IndividualCell_Intensity_RadialProfile_Median_SNCA 1044.415 125.25661941752202
# IndividualCell_Intensity_RadialProfile_Q1_SNCA 710.8154999999999 60.312460918571695
# IndividualCell_Intensity_RadialProfile_Q3_SNCA 1330.3600000000001 180.92175095874478
# IndividualCell_Intensity_RadialProfile_SlopeFit_SNCA -4.961825 2.404854581591776
# IndividualCell_Intensity_RadialProfile_StdCoeffVar_SNCA 27.29675 13.014126373609146
# IndividualCell_Intensity_RadialProfile_Std_SNCA 182.836 35.66002821732184
# IndividualCell_Intensity_SumIntensity_SNCA 3868945.0 998135.9963137191
# IndividualCell_Surface_MeanSurface_SNCA 5022.1900000000005 1086.3909193767392
# Membrane_Intensity_MeanIntensity_MAP2 483.029 22.009047811121402
# Membrane_Intensity_MeanIntensity_SNCA 668.731 42.04110691382022
# Membrane_Intensity_MeanIntensity_TH 307.264 46.9870784843292
# Membrane_Surface_SurfacePerNuclei_MAP2 579.2665 178.92517499064155
# Membrane_Surface_SurfacePerNuclei_SNCA 96.58635 33.760933365530185
# Membrane_Surface_SurfacePerNuclei_TH 280.11699999999996 96.00876003913524
# Nuclei_Living_Ratio_MAP2 0.3260415 0.05679733009593229
# Nuclei_Living_Ratio_MAP2_SNCA 0.273734 0.050033313656591964
# Nuclei_Living_Ratio_TH_SNCA 0.287553 0.0602239267310787
# Nuclei_Surface_MeanArea 1085.21 36.944650284721014
# [DATA NORMALIZED]
# Mut;DMSO          74
# WT;DMSO           53
# PEP005;WT          6
# Mut;Prostratin     6
# Mut;PEP005         6
# Prostratin;WT      5
# Name: tags, dtype: int64
# Mut;DMSO    266
# WT;DMSO     169
# Name: tags, dtype: int64

# %% [markdown]
# ### Summary of processed dataframe

# %%
X_training.describe(include='all')
# Out:
#        Cell_Correlation_MAP2_SNCA  Cell_Correlation_TH_SNCA  \
# count                  127.000000                127.000000
# mean                     0.159843                  0.373375
# std                      0.956866                  1.179121
# min                     -1.769580                 -1.431027
# 25%                     -0.675902                 -0.590240
# 50%                      0.166256                  0.313392
# 75%                      0.901497                  1.021614
# max                      2.298780                  3.465248
#
#        Cell_Correlation_VanSteelselsMeanX_TH_SNCA  \
# count                                  127.000000
# mean                                     0.524598
# std                                      1.629339
# min                                     -2.115988
# 25%                                     -0.803187
# 50%                                      0.157542
# 75%                                      1.336840
# max                                      5.421876
#
#        Cell_Correlation_VanSteelselsMeanY_TH_SNCA  \
# count                                  127.000000
# mean                                     0.736449
# std                                      1.848988
# min                                     -2.261464
# 25%                                     -0.625729
# 50%                                      0.301061
# 75%                                      1.619997
# max                                      7.739980
#
#        Cell_Correlation_VanSteelselsSigmaX_TH_SNCA  \
# count                                   127.000000
# mean                                      0.675649
# std                                       1.569186
# min                                      -1.161256
# 25%                                      -0.596557
# 50%                                       0.354079
# 75%                                       1.335957
# max                                       6.121490
#
#        Cell_Correlation_VanSteelselsSigmaY_TH_SNCA  \
# count                                   127.000000
# mean                                      0.701861
# std                                       1.582379
# min                                      -1.176042
# 25%                                      -0.599841
# 50%                                       0.376693
# 75%                                       1.420095
# max                                       6.019560
#
#        Cell_Intensity_MeanIntensity_MAP2  Cell_Intensity_MeanIntensity_SNCA  \
# count                         127.000000                         127.000000
# mean                           -0.390494                          -0.274674
# std                             1.111833                           1.093672
# min                            -2.867262                          -1.929238
# 25%                            -1.157536                          -1.061405
# 50%                            -0.508714                          -0.383489
# 75%                             0.362632                           0.289615
# max                             2.831972                           4.032421
#
#        Cell_Intensity_MeanIntensity_TH  \
# count                       127.000000
# mean                          0.082790
# std                           0.923922
# min                          -1.341792
# 25%                          -0.648337
# 50%                          -0.066932
# 75%                           0.617706
# max                           2.844629
#
#        Cell_Intensity_SumIntensityPerNuclei_SNCA  ...  \
# count                                 127.000000  ...
# mean                                   -0.877727  ...
# std                                     1.380993  ...
# min                                    -3.354132  ...
# 25%                                    -2.066817  ...
# 50%                                    -1.114063  ...
# 75%                                     0.116467  ...
# max                                     3.014486  ...
#
#        Membrane_Intensity_MeanIntensity_MAP2  \
# count                             127.000000
# mean                               -0.269412
# std                                 1.038906
# min                                -2.353850
# 25%                                -1.018717
# 50%                                -0.264800
# 75%                                 0.397746
# max                                 2.386428
#
#        Membrane_Intensity_MeanIntensity_SNCA  \
# count                             127.000000
# mean                                0.136700
# std                                 1.066527
# min                                -2.584780
# 25%                                -0.549331
# 50%                                -0.001237
# 75%                                 0.774837
# max                                 3.653424
#
#        Membrane_Intensity_MeanIntensity_TH  \
# count                           127.000000
# mean                              0.695735
# std                               1.361007
# min                              -1.275606
# 25%                              -0.226679
# 50%                               0.443398
# 75%                               1.264092
# max                               5.263511
#
#        Membrane_Surface_SurfacePerNuclei_MAP2  \
# count                              127.000000
# mean                                -0.186827
# std                                  1.039066
# min                                 -2.482834
# 25%                                 -0.882615
# 50%                                 -0.245541
# 75%                                  0.504739
# max                                  2.545776
#
#        Membrane_Surface_SurfacePerNuclei_SNCA  \
# count                              127.000000
# mean                                -0.599038
# std                                  1.192256
# min                                 -2.583341
# 25%                                 -1.522753
# 50%                                 -0.723711
# 75%                                  0.115715
# max                                  2.766827
#
#        Membrane_Surface_SurfacePerNuclei_TH  Nuclei_Living_Ratio_MAP2  \
# count                            127.000000                127.000000
# mean                              -0.325353                 -1.182236
# std                                1.073824                  1.712144
# min                               -2.330588                 -4.482832
# 25%                               -1.054050                 -2.747532
# 50%                               -0.365165                 -1.115008
# 75%                                0.136092                  0.119055
# max                                2.849625                  2.356915
#
#        Nuclei_Living_Ratio_MAP2_SNCA  Nuclei_Living_Ratio_TH_SNCA  \
# count                     127.000000                   127.000000
# mean                       -1.144052                    -0.480277
# std                         1.643502                     1.258558
# min                        -4.328938                    -3.204753
# 25%                        -2.640221                    -1.348517
# 50%                        -1.061373                    -0.375316
# 75%                         0.157925                     0.253197
# max                         2.468375                     2.948064
#
#        Nuclei_Surface_MeanArea
# count               127.000000
# mean                 -0.551979
# std                   1.259586
# min                  -3.162325
# 25%                  -1.578578
# 50%                  -0.487486
# 75%                   0.206119
# max                   3.109246
#
# [8 rows x 108 columns]

# %% [markdown]
# ### Inspect individual image features
# Each image feature can be plotted for both reference classes. Each data point represent data from a single well.

# %%
# df_ctrls = main_df[main_df.tags.isin([ctrl_neg, ctrl_pos])]

# df_ctrls_neg = df_ctrls[df_ctrls.tags==ctrl_neg]
# df_ctrls_pos = df_ctrls[df_ctrls.tags==ctrl_pos]

# for col in df_ctrls.columns:
    
#     if col != 'tags':

#         fig = px.histogram(df_ctrls, x=col, color="tags", title=col, nbins=100)
#         fig.show() 

#         feat_zfactor = 1 - 3*(df_ctrls_neg[col].std()+df_ctrls_pos[col].std()) / np.abs(df_ctrls_neg[col].mean()-df_ctrls_pos[col].mean())

#         print('ZFactor', col, feat_zfactor)

# %% [markdown]
# ### Define Cross Validation with Z Factor as score for Classification Methods :
# Computes the Z Factors in function of N different shuffled training/testing sets

# %%
def cross_valid_z_prime(model, X, labels, iter_nb, train_set_proportion):

    list_z_train = []
    list_z_test = []

    for i in range(iter_nb):
        x_train, x_test, y_train, y_test = train_test_split(X, labels, train_size=train_set_proportion, stratify=labels,
                                                            random_state=i)
        model.fit(x_train, y_train)

        accuracy_train = model.score(x_train, y_train)
        accuracy_test = model.score(x_test, y_test)

        x_neg_train = model.transform(x_train[y_train == 0])
        x_pos_train = model.transform(x_train[y_train == 1])

        z_train = 1.0 - 3.0 * (np.std(x_neg_train) + np.std(x_pos_train)) / np.abs(
            np.mean(x_neg_train) - np.mean(x_pos_train))

        x_neg_test = model.transform(x_test[y_test == 0])
        x_pos_test = model.transform(x_test[y_test == 1])

        z_test = 1.0 - 3.0 * (np.std(x_neg_test) + np.std(x_pos_test)) / np.abs(np.mean(x_neg_test) - np.mean(x_pos_test))

        list_z_train.append(z_train)
        list_z_test.append(z_test)

    return list_z_train, list_z_test

def cross_valid_z_prime_svm(model, X, labels, iter_nb, train_set_proportion, output_path):

    list_z_train = []
    list_z_test = []

    for i in range(iter_nb):
        x_train, x_test, y_train, y_test = train_test_split(X, labels, train_size=train_set_proportion, stratify=labels,
                                                            random_state=i)

        model.fit(x_train, y_train)

        accuracy_train = model.score(x_train, y_train)
        accuracy_test = model.score(x_test, y_test)

        x_neg_train = model.predict_proba(x_train[y_train == 0])[:,0]
        x_pos_train = model.predict_proba(x_train[y_train == 1])[:,0]

        z_train = 1.0 - 3.0 * (np.std(x_neg_train) + np.std(x_pos_train)) / np.abs(
            np.mean(x_neg_train) - np.mean(x_pos_train))

        x_neg_test = model.predict_proba(x_test[y_test == 0])[:,0]
        x_pos_test = model.predict_proba(x_test[y_test == 1])[:,0]

        z_test = 1.0 - 3.0 * (np.std(x_neg_test) + np.std(x_pos_test)) / np.abs(np.mean(x_neg_test) - np.mean(x_pos_test))

        list_z_train.append(z_train)
        list_z_test.append(z_test)

    return list_z_train, list_z_test

def cross_valid_z_prime_linear_svm(model, X, labels, iter_nb, train_set_proportion, output_path):

    list_z_train = []
    list_z_test = []

    for i in range(iter_nb):
        x_train, x_test, y_train, y_test = train_test_split(X, labels, train_size=train_set_proportion, stratify=labels,
                                                            random_state=i)

        model.fit(x_train, y_train)

        accuracy_train = model.score(x_train, y_train)
        accuracy_test = model.score(x_test, y_test)

        x_neg_train = model.decision_function(x_train[y_train == 0])
        x_pos_train = model.decision_function(x_train[y_train == 1])

        z_train = 1.0 - 3.0 * (np.std(x_neg_train) + np.std(x_pos_train)) / np.abs(
            np.mean(x_neg_train) - np.mean(x_pos_train))

        x_neg_test = model.decision_function(x_test[y_test == 0])
        x_pos_test = model.decision_function(x_test[y_test == 1])

        z_test = 1.0 - 3.0 * (np.std(x_neg_test) + np.std(x_pos_test)) / np.abs(np.mean(x_neg_test) - np.mean(x_pos_test))

        list_z_train.append(z_train)
        list_z_test.append(z_test)

    return list_z_train, list_z_test

# %% [markdown]
# ## LDA classifier with all image features : Plate 1
# Regularized Classification of the data using LDA

# %%
output_path_all = output_path+'/lda_all_features/'

if not os.path.exists(output_path_all):
	os.makedirs(output_path_all, exist_ok=True)

train_set_proportion = 0.8
shrink = 'auto'

le = LabelEncoder() 
Y_training = le.fit_transform(Y_training)

x_train, x_test, y_train, y_test = train_test_split(X_training, Y_training, train_size=train_set_proportion, stratify=Y_training, random_state=100)

lda_analysis = LDA(solver='eigen', n_components=1, shrinkage=shrink)
lda_analysis.fit(x_train, y_train)

LDA_train = lda_analysis.transform(x_train)
LDA_test = lda_analysis.transform(x_test)

df_training_set = pd.DataFrame()

with sns.axes_style("white"), sns.axes_style("ticks"), sns.plotting_context("talk"):
	fig, axes = plt.subplots(figsize=(16, 6), nrows=1, ncols=2)
	axes[0].hist(LDA_train[y_train==0], label=ctrl_neg)
	axes[0].hist(LDA_train[y_train==1], label=ctrl_pos)
	axes[0].set_title('LDA Training Set')
	axes[1].hist(LDA_test[y_test==0], label=ctrl_neg)
	axes[1].hist(LDA_test[y_test==1], label=ctrl_pos)
	axes[1].set_title('LDA Testing Set')
	plt.tight_layout()
	sns.despine()
	plt.savefig(output_path_all+'LDA_training_test_set_shrinkage_'+str(shrink)+'_all_set.pdf', bbox_inches='tight')
	plt.show()

from sklearn.model_selection import cross_val_score
scores = cross_val_score(lda_analysis, X_training, Y_training, cv=10)
print("Cross valid Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std()))
print('\n')

list_z_train, list_z_test = cross_valid_z_prime(lda_analysis, X_training, Y_training, 25, train_set_proportion)

xpoints = range(len(list_z_test))

training = ['Training'] * len(list_z_train)
testing = ['Testing'] * len(list_z_test)

training_df = pd.DataFrame(
    {'Y': list_z_train,
     'X': xpoints,
     'Hue': training
    })

testing_df = pd.DataFrame(
    {'Y': list_z_test,
     'X': xpoints,
     'Hue': testing

    })
test_train = training_df.append(testing_df).reset_index(drop=True)

sns.set_context("talk")                
ax = sns.lineplot(data=test_train, x='X', y='Y', hue='Hue')
ax.set(xlabel='Cross Validation Dataset', ylabel='Z factor')
plt.hlines(np.mean(list_z_train), 0, len(list_z_train)-1, colors=sns.color_palette()[0], linestyles='dashed')
plt.hlines(np.mean(list_z_test), 0, len(list_z_test)-1, colors=sns.color_palette()[1], linestyles='dashed')
sns.despine()
# Put the legend out of the figure and remove title
handles, labels = ax.get_legend_handles_labels()
ax.legend(['Z Factor Training Set, Avg = '+"%.2f" % np.mean(list_z_train), 
           'Z Factor Testing Set, Avg = '+"%.2f" % np.mean(list_z_test)], handles=handles[2:], labels=labels[2:], bbox_to_anchor=(1.02, 0.3), loc=3, borderaxespad=0., 
           frameon=False)
plt.savefig(output_path_all+'LDA_CV_ZFactor.pdf', bbox_inches='tight')
# Out:
# Cross valid Accuracy: 1.00 (+/- 0.00)

# %% [markdown]
# ## Correlations : Feature Correlations :

# %%
output_path_corr = output_path+'/Pearson_Correlations/'

if not os.path.exists(output_path_corr):
	os.makedirs(output_path_corr, exist_ok=True)

correlations = X_training.corr().abs()

sns.set_context("talk", font_scale=0.5)
f, ax = plt.subplots(figsize=(20, 20))
h = sns.heatmap(correlations, cmap='coolwarm')
plt.title('Pearson Correlations, All Features')
plt.tight_layout()
plt.savefig(output_path_corr+"pearson_correlations_all_features.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Loop through correlation thresholds
# The goal is to identify the correlation threshold yielding the highest Z factor between the two reference classes as determined by LDA.

# %%
def apply_threhold_correlations(X, thr):
    corr_between_features = thr
    new_correlations = X.corr().abs()

    upper = new_correlations.where(np.triu(np.ones(new_correlations.shape), k=1).astype(np.bool))
    to_drop = [column for column in upper.columns if any(upper[column] > corr_between_features)]

    # print('Dropped Features :')
    # display(to_drop)
    print('New Feature Size = ', len(X.columns)-len(to_drop))

    df_X_without_correlated = X.copy()
    df_X_without_correlated.drop(to_drop, axis=1, inplace=True)

    return df_X_without_correlated

# %%
def classif_lda(X, Y, train_set_proportion = 0.8, shrink = 'auto'):

    x_train, x_test, y_train, y_test = train_test_split(X, Y, train_size=train_set_proportion, stratify=Y, random_state=100)

    lda_analysis = LDA(solver='eigen', n_components=1, shrinkage=shrink)

    # print(x_train.columns)

    lda_analysis.fit(x_train, y_train)

    from sklearn.model_selection import cross_val_score
    scores = cross_val_score(lda_analysis, X, Y, cv=10)
    print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std()))

    list_z_train, list_z_test = cross_valid_z_prime(lda_analysis, X, Y, 25, train_set_proportion)

    return scores.mean(), list_z_train, list_z_test

# %% [markdown]
# ### Plotting of correlation thresholds vs Z Factor and CV Accuracy

# %%
list_df_thr_correlations = []
list_thr = []

for thr in np.arange(0.5, 1.0, 0.05):
    list_df_thr_correlations.append(apply_threhold_correlations(X_training, thr))
    list_thr.append(thr)

list_scores = []
list_avg_z_train = []
list_avg_z_test = []

for df_data in list_df_thr_correlations:
    scores, z_train, z_test = classif_lda(df_data, Y_training, train_set_proportion = 0.8, shrink = 'auto')
    list_scores.append(scores)
    list_avg_z_train.append(np.mean(z_train))
    list_avg_z_test.append(np.mean(z_test))

# Generating dataframe for plotting
training = ['Z Factor (LDA, Training set)'] * len(list_avg_z_train)
testing = ['Z Factor (LDA, Testing set)'] * len(list_avg_z_test)
LDA_CV_score = ['CV Score (LDA)'] * len(list_scores)

df_list_scores = pd.DataFrame(
    {'Y': list_scores,
     'X': list_thr,
     'Hue': LDA_CV_score
    })

df_avg_z_train = pd.DataFrame(
    {'Y': list_avg_z_train,
     'X': list_thr,
     'Hue': training
    })

df_avg_z_test = pd.DataFrame(
    {'Y': list_avg_z_test,
     'X': list_thr,
     'Hue': testing
    })

test_train = df_avg_z_train.append(df_avg_z_test).reset_index(drop=True)

# Plotting
sns.set_context("talk")                
ax = sns.lineplot(data=test_train, x='X', y='Y', hue='Hue')
ax.set(xlabel='Pearson correlation threshold for feature reduction', ylabel='Z factor (LDA)')
sns.despine()
handles, labels = ax.get_legend_handles_labels()
ax.legend(handles=handles[0:], labels=labels[0:], bbox_to_anchor=(1.02, 0.3), loc=3, borderaxespad=0., 
           frameon=False)
plt.savefig(output_path_corr+"lda_zfactor_function_correlation_thr.pdf", bbox_inches='tight')
plt.show()

ax1 = sns.lineplot(data=df_list_scores, x='X', y='Y', hue='Hue')
ax1.set(xlabel='Pearson correlation threshold for feature reduction', ylabel='Accuracy (LDA)')
sns.despine()
handles, labels = ax1.get_legend_handles_labels()
ax1.legend(handles=handles[0:], labels=labels[0:], bbox_to_anchor=(1.02, 0.3), loc=3, borderaxespad=0., 
           frameon=False)
plt.savefig(output_path_corr+"lda_CVscore_function_correlation_thr.pdf", bbox_inches='tight')
plt.show()

threshold_validated = list_thr[np.argmax(list_avg_z_test)]

print('Threshold maximizing LDA Z Factor Test: ', threshold_validated)
# Out:
# New Feature Size =  11
# New Feature Size =  14
# New Feature Size =  21
# New Feature Size =  25
# New Feature Size =  28
# New Feature Size =  33
# New Feature Size =  36
# New Feature Size =  39
# New Feature Size =  45
# New Feature Size =  54
# Accuracy: 0.87 (+/- 0.08)
# Accuracy: 0.94 (+/- 0.05)
# Accuracy: 0.99 (+/- 0.03)
# Accuracy: 0.99 (+/- 0.03)
# Accuracy: 0.99 (+/- 0.03)
# Accuracy: 0.99 (+/- 0.03)
# Accuracy: 1.00 (+/- 0.00)
# Accuracy: 1.00 (+/- 0.00)
# Accuracy: 1.00 (+/- 0.00)
# Accuracy: 1.00 (+/- 0.00)
# Threshold maximizing LDA Z Factor Test:  0.9000000000000004

# %% [markdown]
# ### Remove Correlated Features above the defined threshold :

# %%
corr_between_features = 1.0 

if remove_corr == True:
    corr_between_features = threshold_validated #correlation threshold between features
    
new_correlations = X_training.corr().abs()

upper = new_correlations.where(np.triu(np.ones(new_correlations.shape), k=1).astype(np.bool))
to_drop = [column for column in upper.columns if any(upper[column] > corr_between_features)]

print('Dropped Features :')
display(to_drop)
display(len(to_drop))

df_X_without_correlated = X_training.copy()
df_X_without_correlated.drop(to_drop, axis=1, inplace=True)

display(df_X_without_correlated.columns)
display('FinalFeatures : ', len(df_X_without_correlated.columns))

sns.set_context("talk", font_scale=0.9)
f, ax = plt.subplots(figsize=(20, 20))
h = sns.heatmap(df_X_without_correlated.corr().abs(), cmap='coolwarm')
plt.title('Pearson Correlations, All Features')
plt.tight_layout()
plt.savefig(output_path_corr+"person_correlations_after_selection.pdf", bbox_inches='tight')
plt.show()
# Out:
# Dropped Features :
# []
# 0
# Index(['Cell_Correlation_MAP2_SNCA', 'Cell_Correlation_TH_SNCA',
#        'Cell_Correlation_VanSteelselsMeanX_TH_SNCA',
#        'Cell_Correlation_VanSteelselsMeanY_TH_SNCA',
#        'Cell_Correlation_VanSteelselsSigmaX_TH_SNCA',
#        'Cell_Correlation_VanSteelselsSigmaY_TH_SNCA',
#        'Cell_Intensity_MeanIntensity_MAP2',
#        'Cell_Intensity_MeanIntensity_SNCA', 'Cell_Intensity_MeanIntensity_TH',
#        'Cell_Intensity_SumIntensityPerNuclei_SNCA',
#        ...
#        'Membrane_Intensity_MeanIntensity_MAP2',
#        'Membrane_Intensity_MeanIntensity_SNCA',
#        'Membrane_Intensity_MeanIntensity_TH',
#        'Membrane_Surface_SurfacePerNuclei_MAP2',
#        'Membrane_Surface_SurfacePerNuclei_SNCA',
#        'Membrane_Surface_SurfacePerNuclei_TH', 'Nuclei_Living_Ratio_MAP2',
#        'Nuclei_Living_Ratio_MAP2_SNCA', 'Nuclei_Living_Ratio_TH_SNCA',
#        'Nuclei_Surface_MeanArea'],
#       dtype='object', length=108)
# 'FinalFeatures : '
# 108

# %% [markdown]
# ### LightGBM Analysis
# Fit of two previously selected reference classes to identify features which contribute the most to reference class separation.

# %%
le = LabelEncoder() 
trainY = le.fit_transform(Y_training)

n=200
feature_importances = np.zeros(df_X_without_correlated.shape[1])
for i in range(n): 
   
    lgb_model = lgb.LGBMClassifier( boosting_type = 'goss', n_estimators = 10000, class_weight = 'balanced')
    train_features, valid_features, train_y, valid_y = train_test_split(df_X_without_correlated, trainY, test_size = 0.1, random_state = i)      
    lgb_model.fit(train_features, train_y, early_stopping_rounds=100, eval_set = [(valid_features, valid_y)], 
              eval_metric = 'auc', verbose = 0)       
    feature_importances += lgb_model.feature_importances_

feature_importances = feature_importances / n
feature_importances = pd.DataFrame({'feature': list(df_X_without_correlated.columns), 'importance': feature_importances}).sort_values('importance', ascending = False)

output_path_LGBM = output_path+'/LightGBM_after_correlations/'

if not os.path.exists(output_path_LGBM):
	os.makedirs(output_path_LGBM, exist_ok=True)

# Evaluate number of features without any significnace for LightGBM classification
zero_features = list(feature_importances[feature_importances['importance'] == 0.0]['feature'])
print('There are %d features with 0.0 importance' % len(zero_features))

feature_importances = feature_importances.sort_values('importance', ascending=False).reset_index()

# Normalize the feature importances to add up to one
feature_importances['importance_normalized'] = feature_importances['importance'] / feature_importances['importance'].sum()
feature_importances['cumulative_importance'] = np.cumsum(feature_importances['importance_normalized'])

#plt.figure(figsize=(10, 20))
#ax = plt.subplot()

df_feature_importances = pd.DataFrame(
    {'Features': feature_importances['feature'],
     'Importance (fraction)': feature_importances['importance_normalized'],
     'cumulative_importance': feature_importances['cumulative_importance']
    })

feature_importances_head20 = feature_importances.head(20)
print(feature_importances_head20)

sns.set_context("talk", font_scale=0.5)
ax = sns.barplot(x="importance_normalized", y="feature", data=feature_importances_head20, color="#1f77b4")
ax.set(xlabel='Feature importance (ratio)', ylabel='')
sns.despine()
plt.savefig(output_path_LGBM+"LightGBM_FeatureContributions_after_PearsonThreshold.pdf", bbox_inches='tight')
plt.show()

# Cumulative importance plot
feature_importances['position'] = list(range(len(feature_importances)))
sns.set_context("talk")
ax1 = sns.lineplot(data=feature_importances, x='position', y='cumulative_importance')
ax1.set(xlabel='Number of Features', ylabel='Cumulative Importance')
sns.despine()
plt.savefig(output_path_LGBM+"LightGBM_CumulativeImportance.pdf", bbox_inches='tight')
plt.show()

df_feature_ranking_lgbm_pl3 = pd.DataFrame()
l_feat = []
l_rank = []

for i, f in enumerate(feature_importances['feature']):
    l_rank.append(i+1)
    l_feat.append(f)

df_feature_ranking_lgbm_pl3["Feature"] = l_feat
df_feature_ranking_lgbm_pl3["Ranking_3"] = l_rank

df_feature_ranking_lgbm_pl3.to_csv("feat_ranking_lgbm_pl3.csv", index=None)
# Out:
# There are 26 features with 0.0 importance
#     index                                            feature  importance  \
# 0     104                           Nuclei_Living_Ratio_MAP2       2.495
# 1       0                         Cell_Correlation_MAP2_SNCA       0.550
# 2       2         Cell_Correlation_VanSteelselsMeanX_TH_SNCA       0.485
# 3       4        Cell_Correlation_VanSteelselsSigmaX_TH_SNCA       0.325
# 4       1                           Cell_Correlation_TH_SNCA       0.295
# 5      20                           Cell_SurfacePerNuclei_TH       0.290
# 6       7                  Cell_Intensity_MeanIntensity_SNCA       0.280
# 7      15                          Cell_Neurites_Length_MAP2       0.265
# 8     102             Membrane_Surface_SurfacePerNuclei_SNCA       0.260
# 9      82                Cytoplasm_Surface_TotalSurface_SNCA       0.240
# 10     97            IndividualCell_Surface_MeanSurface_SNCA       0.240
# 11     80                    Cytoplasm_SurfacePerNuclei_SNCA       0.195
# 12      8                    Cell_Intensity_MeanIntensity_TH       0.195
# 13    101             Membrane_Surface_SurfacePerNuclei_MAP2       0.175
# 14     42           Cell_Texture_SNCA_DifferenceVariance_000       0.135
# 15     87  IndividualCell_Intensity_RadialProfile_MeanCoe...       0.130
# 16     81                 Cytoplasm_SurfacePerNuclei_TH_SNCA       0.120
# 17     12          Cell_Neurites_BranchingPointsPerNuclei_TH       0.120
# 18      5        Cell_Correlation_VanSteelselsSigmaY_TH_SNCA       0.115
# 19     19                         Cell_SurfacePerNuclei_SNCA       0.105
#
#     importance_normalized  cumulative_importance
# 0                0.269876               0.269876
# 1                0.059492               0.329367
# 2                0.052461               0.381828
# 3                0.035154               0.416982
# 4                0.031909               0.448891
# 5                0.031368               0.480260
# 6                0.030287               0.510546
# 7                0.028664               0.539210
# 8                0.028123               0.567334
# 9                0.025960               0.593294
# 10               0.025960               0.619254
# 11               0.021092               0.640346
# 12               0.021092               0.661439
# 13               0.018929               0.680368
# 14               0.014602               0.694970
# 15               0.014062               0.709032
# 16               0.012980               0.722012
# 17               0.012980               0.734992
# 18               0.012439               0.747431
# 19               0.011357               0.758789

# %%
print('Plotting metrics recorded during training...')

ax = lgb.plot_metric( lgb_model)
plt.show()
# Out:
# Plotting metrics recorded during training...

# %% [markdown]
# ### Select number of features for LDA based on LightGBM classifier
# Pick the number of features that will be used for the subsequent LDA. You can choose all features or select only the contributing ones as determined above. EXAMPLE: If total number of features is 105 and 12 are not contributing, select 93 features for LDA.

# %%
n_feat = len(feature_importances['feature'])

nb_feat_select = n_feat - 26

display(nb_feat_select)
# Out:
# 82

# %% [markdown]
# ### LDA Analysis (with feature selection by previous Pearson Correlations Threshold)

# %%
output_path_all = output_path+'/LDA_features_after_correlations/'

if not os.path.exists(output_path_all):
	os.makedirs(output_path_all, exist_ok=True)

train_set_proportion = 0.8
shrink = 'auto'

subset_columns = (feature_importances['feature'])[0:nb_feat_select]
print(subset_columns)

X_subset = df_X_without_correlated[subset_columns]

x_train, x_test, y_train, y_test = train_test_split(X_subset, Y_training, train_size=train_set_proportion, stratify=Y_training, random_state=100)

lda_analysis = LDA(solver='eigen', n_components=1, shrinkage=shrink)

print(x_train.columns)

lda_analysis.fit(x_train, y_train)

LDA_train = lda_analysis.transform(x_train)
LDA_test = lda_analysis.transform(x_test)

from sklearn.model_selection import cross_val_score
scores = cross_val_score(lda_analysis, X_subset, Y_training, cv=10)
print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std()))


with sns.axes_style("white"), sns.plotting_context("talk"):
	fig, axes = plt.subplots(figsize=(16, 6), nrows=1, ncols=2)
	axes[0].hist(LDA_train[y_train==0], label=ctrl_neg)
	axes[0].hist(LDA_train[y_train==1], label=ctrl_pos)
	axes[0].set_title('LDA Training Set')
	axes[1].hist(LDA_test[y_test==0], label=ctrl_neg)
	axes[1].hist(LDA_test[y_test==1], label=ctrl_pos)
	axes[1].set_title('LDA Testing Set')
	plt.tight_layout()
	sns.despine()
	plt.savefig(output_path_all+'LDA_training_test_set_shrinkage_'+str(shrink)+'_after_correlations.pdf', bbox_inches='tight')
	plt.show()

X_all_cpds_subset = X_subset[subset_columns]

main_df_wo_outliers_testing = pd.DataFrame()

main_df_wo_outliers_testing = remove_outliers_by_plate(main_testing, outliers_sigma, 'std', ctrl_neg, ctrl_pos)
main_df_normed_testing = norm_centered_by_plate(main_df_wo_outliers_testing, 'std', ctrl_neg, ctrl_pos)

main_df_normed_testing_subset = main_df_normed_testing.reset_index()
Y_testing = []
l_tags = []

for i, t in enumerate(main_df_normed_testing_subset.tags):
    pl = main_df_normed_testing_subset['Plate'][i]
    new_t = t+'_'+pl
    l_tags.append(new_t)

Y_testing = l_tags

X_testing_subset = main_df_normed_testing_subset.drop(['tags'], axis=1)
X_testing_subset = X_testing_subset[subset_columns]

LDA_dmso_and_cpds_subset_training = lda_analysis.transform(X_all_cpds_subset)
LDA_dmso_and_cpds_subset_testing = lda_analysis.transform(X_testing_subset)

X_all_cpds_subset_lda1 = X_all_cpds_subset.copy()

X_all_cpds_subset_lda1['LDA_Projection'] = LDA_dmso_and_cpds_subset_training[:,0]
X_all_cpds_subset_lda1['tags'] = Y_all_cpds_training

X_all_cpds_subset_lda2 = X_testing_subset.copy()
X_all_cpds_subset_lda2['LDA_Projection'] = LDA_dmso_and_cpds_subset_testing[:,0]
X_all_cpds_subset_lda2['tags'] = Y_testing

X_all_cpds_subset_lda = pd.concat([X_all_cpds_subset_lda1, X_all_cpds_subset_lda2])

X_all_cpds_subset_lda = X_all_cpds_subset_lda[X_all_cpds_subset_lda.tags.str.contains('DMSO')]

list_z_train, list_z_test = cross_valid_z_prime(lda_analysis, X_all_cpds_subset, Y_training, 25, train_set_proportion)

xpoints = range(len(list_z_test))

training = ['Training'] * len(list_z_train)
testing = ['Testing'] * len(list_z_test)

training_df = pd.DataFrame(
    {'Y': list_z_train,
     'X': xpoints,
     'Hue': training
    })

testing_df = pd.DataFrame(
    {'Y': list_z_test,
     'X': xpoints,
     'Hue': testing
    })

test_train = training_df.append(testing_df).reset_index(drop=True)

sns.set_context("talk")                
ax = sns.lineplot(data=test_train, x='X', y='Y', hue='Hue')
ax.set(xlabel='Cross Validation Dataset', ylabel='Z factor')
plt.hlines(np.mean(list_z_train), 0, len(list_z_train)-1, colors=sns.color_palette()[0], linestyles='dashed')
plt.hlines(np.mean(list_z_test), 0, len(list_z_test)-1, colors=sns.color_palette()[1], linestyles='dashed')
sns.despine()
# Put the legend out of the figure and remove title
handles, labels = ax.get_legend_handles_labels()
ax.legend(['Z Factor Training Set, Avg = '+"%.2f" % np.mean(list_z_train), 
           'Z Factor Testing Set, Avg = '+"%.2f" % np.mean(list_z_test)], handles=handles[2:], labels=labels[2:], bbox_to_anchor=(1.02, 0.3), loc=3, borderaxespad=0., 
           frameon=False)
plt.savefig(output_path_all+"LDA_Cross_Validation_Dataset"+str(shrink)+"_after_correlations.pdf", bbox_inches='tight')
plt.show()

# Plotting
sns.set_context("talk")
fig,ax = plt.subplots(figsize=(8,4))
ax = sns.boxplot(x='tags', y='LDA_Projection', data=X_all_cpds_subset_lda, width=0.7, showfliers=False, zorder=1,
                 notch=1, order=order) 
# Transparancy of boxplot filling color
for patch in ax.artists:
    r, g, b, a = patch.get_facecolor()
    patch.set_facecolor((r, g, b, 0))
s = sns.stripplot(x='tags', y='LDA_Projection', data=X_all_cpds_subset_lda, size=10, alpha=0.2, jitter=0.2, order=order,
                  zorder=0, palette='tab10')
from statannot import add_stat_annotation
# Stat annotations
add_stat_annotation(s, data=X_all_cpds_subset_lda, x='tags', y='LDA_Projection', box_pairs=box_pairs,
               loc='outside', verbose=1, test='Mann-Whitney', comparisons_correction=None,
               perform_stat_test=True, #order=order,
               color='0.2', linewidth=1.5,
               fontsize=20)
s.set(xlabel=None)
s.set_xticklabels(s.get_xticklabels(),rotation=45, ha='right', rotation_mode="anchor")
sns.despine()
plt.savefig(output_path_all+"LDA_Projection_All_Conditions_after_correlations_shrinkage_"+str(shrink)+".pdf", bbox_inches='tight')
plt.show()
# Out:
# 0                              Nuclei_Living_Ratio_MAP2
# 1                            Cell_Correlation_MAP2_SNCA
# 2            Cell_Correlation_VanSteelselsMeanX_TH_SNCA
# 3           Cell_Correlation_VanSteelselsSigmaX_TH_SNCA
# 4                              Cell_Correlation_TH_SNCA
#                             ...
# 77    IndividualCell_Intensity_RadialProfile_Interce...
# 78            Cell_Texture_SNCA_AngularSecondMoment_135
# 79            Cell_Texture_SNCA_AngularSecondMoment_045
# 80                    Cell_Texture_SNCA_Correlation_090
# 81                     Cell_Texture_SNCA_SumEntropy_090
# Name: feature, Length: 82, dtype: object
# Index(['Nuclei_Living_Ratio_MAP2', 'Cell_Correlation_MAP2_SNCA',
#        'Cell_Correlation_VanSteelselsMeanX_TH_SNCA',
#        'Cell_Correlation_VanSteelselsSigmaX_TH_SNCA',
#        'Cell_Correlation_TH_SNCA', 'Cell_SurfacePerNuclei_TH',
#        'Cell_Intensity_MeanIntensity_SNCA', 'Cell_Neurites_Length_MAP2',
#        'Membrane_Surface_SurfacePerNuclei_SNCA',
#        'Cytoplasm_Surface_TotalSurface_SNCA',
#        'IndividualCell_Surface_MeanSurface_SNCA',
#        'Cytoplasm_SurfacePerNuclei_SNCA', 'Cell_Intensity_MeanIntensity_TH',
#        'Membrane_Surface_SurfacePerNuclei_MAP2',
#        'Cell_Texture_SNCA_DifferenceVariance_000',
#        'IndividualCell_Intensity_RadialProfile_MeanCoeffVar_SNCA',
#        'Cytoplasm_SurfacePerNuclei_TH_SNCA',
#        'Cell_Neurites_BranchingPointsPerNuclei_TH',
#        'Cell_Correlation_VanSteelselsSigmaY_TH_SNCA',
#        'Cell_SurfacePerNuclei_SNCA',
#        'Cell_Texture_SNCA_AngularSecondMoment_000',
#        'Cell_Neurites_LengthPerNuclei_MAP2', 'Nuclei_Living_Ratio_MAP2_SNCA',
#        'Cell_Neurites_LengthPerNuclei_TH',
#        'Cell_Intensity_SumIntensityPerNuclei_SNCA',
#        'Cell_SurfacePerNuclei_TH_SNCA',
#        'Cell_Texture_SNCA_InfoMeasuresOfCorr2_090',
#        'Cell_Texture_SNCA_InfoMeasuresOfCorr2_045',
#        'Cell_Texture_SNCA_InfoMeasuresOfCorr2_135',
#        'IndividualCell_Intensity_SumIntensity_SNCA',
#        'Membrane_Intensity_MeanIntensity_TH',
#        'Cell_Texture_SNCA_DifferenceVariance_045',
#        'Cell_SurfacePerNuclei_MAP2_SNCA',
#        'Cell_Texture_SNCA_DifferenceEntropy_000', 'Cell_SurfacePerNuclei_MAP2',
#        'Nuclei_Living_Ratio_TH_SNCA', 'Nuclei_Surface_MeanArea',
#        'Cell_Surface_RatioSurface_TH_SNCA',
#        'Cell_Correlation_VanSteelselsMeanY_TH_SNCA',
#        'Cell_TH_SNCA_Intensity_MeanIntensity_SNCA', 'Cell_Neurites_Length_TH',
#        'Cytoplasm_Intensity_MeanIntensity_SNCA',
#        'IndividualCell_Intensity_RadialProfile_StdCoeffVar_SNCA',
#        'Cell_Neurites_BranchingPointsPerNuclei_MAP2',
#        'Cytoplasm_MAP2_SNCA_Intensity_MeanIntensity_SNCA',
#        'Cell_Texture_SNCA_DifferenceVariance_090',
#        'Cell_TH_SNCA_Intensity_SumIntensityPerNuclei_SNCA',
#        'IndividualCell_Intensity_MeanIntensity_SNCA',
#        'Cell_Texture_SNCA_InfoMeasuresOfCorr1_000',
#        'Cell_Texture_SNCA_Entropy_000', 'Membrane_Surface_SurfacePerNuclei_TH',
#        'Cell_Texture_SNCA_SumEntropy_000',
#        'Cell_Texture_SNCA_DifferenceEntropy_090',
#        'Cell_Texture_SNCA_Contrast_000',
#        'Cell_Texture_SNCA_InfoMeasuresOfCorr1_045',
#        'Cell_MAP2_SNCA_Intensity_MeanIntensity_SNCA',
#        'Cell_Texture_SNCA_InfoMeasuresOfCorr2_000',
#        'Cell_Texture_SNCA_InfoMeasuresOfCorr1_090',
#        'Cell_TH_SNCA_Intensity_MeanIntensity_TH',
#        'Cell_Intensity_MeanIntensity_MAP2', 'Cell_Texture_SNCA_Contrast_135',
#        'IndividualCell_Intensity_RadialProfile_MaxSlope_SNCA',
#        'Cell_Texture_SNCA_DifferenceEntropy_045',
#        'Membrane_Intensity_MeanIntensity_MAP2',
#        'IndividualCell_Intensity_RadialProfile_Mean_SNCA',
#        'Cell_Texture_SNCA_InverseDiffMoment_000',
#        'Cell_Texture_SNCA_InfoMeasuresOfCorr1_135',
#        'Cell_Texture_SNCA_SumEntropy_045',
#        'IndividualCell_Intensity_RadialProfile_MeanGradient_SNCA',
#        'Cell_Texture_SNCA_DifferenceEntropy_135',
#        'Cell_Texture_SNCA_Entropy_045', 'Cell_Texture_SNCA_Entropy_090',
#        'Cell_Texture_SNCA_InverseDiffMoment_045',
#        'Cell_Texture_SNCA_InverseDiffMoment_135',
#        'Membrane_Intensity_MeanIntensity_SNCA',
#        'Cell_Texture_SNCA_SumEntropy_135', 'Cell_Texture_SNCA_SumAverage_000',
#        'IndividualCell_Intensity_RadialProfile_InterceptFit_SNCA',
#        'Cell_Texture_SNCA_AngularSecondMoment_135',
#        'Cell_Texture_SNCA_AngularSecondMoment_045',
#        'Cell_Texture_SNCA_Correlation_090',
#        'Cell_Texture_SNCA_SumEntropy_090'],
#       dtype='object')
# Accuracy: 1.00 (+/- 0.00)
# [DATA BEFORE OUTLIERS:] 482
# CPDS LEN =  24
# CPDS LEN =  23
# [DATA AFTER OUTLIERS:] 305
# Cell_Correlation_MAP2_SNCA 0.299242 0.06713545865240311
# Cell_Correlation_TH_SNCA 0.0680093 0.03703194513580282
# Cell_Correlation_VanSteelselsMeanX_TH_SNCA 25.6531 3.542567460258183
# Cell_Correlation_VanSteelselsMeanY_TH_SNCA 24.7298 3.3412752799624794
# Cell_Correlation_VanSteelselsSigmaX_TH_SNCA 4.31194 2.7164959518300256
# Cell_Correlation_VanSteelselsSigmaY_TH_SNCA 4.30648 2.6813031990467007
# Cell_Intensity_MeanIntensity_MAP2 550.745 30.848118213990087
# Cell_Intensity_MeanIntensity_SNCA 735.855 54.96598507910879
# Cell_Intensity_MeanIntensity_TH 383.301 59.646718609153226
# Cell_Intensity_SumIntensityPerNuclei_SNCA 1517880.0 232235.4814083449
# Cell_MAP2_SNCA_Intensity_MeanIntensity_SNCA 848.966 212.9674549870919
# Cell_Neurites_BranchingPointsPerNuclei_MAP2 1.98571 0.3016647586925544
# Cell_Neurites_BranchingPointsPerNuclei_TH 1.25667 0.2936635699814157
# Cell_Neurites_LengthPerNuclei_MAP2 333.791 40.248410181262926
# Cell_Neurites_LengthPerNuclei_TH 212.403 49.52712102101627
# Cell_Neurites_Length_MAP2 78336.0 16377.848057968633
# Cell_Neurites_Length_TH 78144.0 16152.436209715126
# Cell_SurfacePerNuclei_MAP2 4954.28 402.41838762250006
# Cell_SurfacePerNuclei_MAP2_SNCA 2050.14 184.89674990814888
# Cell_SurfacePerNuclei_SNCA 2061.25 240.24679595958446
# Cell_SurfacePerNuclei_TH 4785.3 351.6309155290956
# Cell_SurfacePerNuclei_TH_SNCA 1958.03 151.94496992147631
# Cell_Surface_RatioSurface_TH_SNCA 0.945697 0.2484172407611847
# Cell_TH_SNCA_Intensity_MeanIntensity_SNCA 791.849 155.1022030814934
# Cell_TH_SNCA_Intensity_MeanIntensity_TH 316.79 37.70562174929205
# Cell_TH_SNCA_Intensity_SumIntensityPerNuclei_SNCA 1593560.0 337767.7074257354
# Cell_Texture_SNCA_AngularSecondMoment_000 0.817995 0.06028469895519069
# Cell_Texture_SNCA_AngularSecondMoment_045 0.812096 0.06069026077191984
# Cell_Texture_SNCA_AngularSecondMoment_090 0.81808 0.06033634824854097
# Cell_Texture_SNCA_AngularSecondMoment_135 0.812459 0.060882823147321706
# Cell_Texture_SNCA_Contrast_000 1.01974 2.0539549341554073
# Cell_Texture_SNCA_Contrast_045 1.55401 2.6632797149103795
# Cell_Texture_SNCA_Contrast_090 1.15189 2.037043962724065
# Cell_Texture_SNCA_Contrast_135 1.71355 2.6705348757475393
# Cell_Texture_SNCA_Correlation_000 984.031 1337.8291403379808
# Cell_Texture_SNCA_Correlation_045 928.79 1273.2042047390328
# Cell_Texture_SNCA_Correlation_090 986.635 1340.1033070380015
# Cell_Texture_SNCA_Correlation_135 934.292 1272.4866172780798
# Cell_Texture_SNCA_DifferenceEntropy_000 0.103868 0.02446726828786706
# Cell_Texture_SNCA_DifferenceEntropy_045 0.118215 0.02541563077386866
# Cell_Texture_SNCA_DifferenceEntropy_090 0.103941 0.024531529004796992
# Cell_Texture_SNCA_DifferenceEntropy_135 0.117292 0.02566174229075106
# Cell_Texture_SNCA_DifferenceVariance_000 1.99e-06 2.0983683454421156e-06
# Cell_Texture_SNCA_DifferenceVariance_045 2.43e-06 2.3566844552684623e-06
# Cell_Texture_SNCA_DifferenceVariance_090 1.99e-06 2.1111580092978653e-06
# Cell_Texture_SNCA_DifferenceVariance_135 2.41e-06 2.390017546181668e-06
# Cell_Texture_SNCA_Entropy_000 0.235587 0.05801405589384418
# Cell_Texture_SNCA_Entropy_045 0.2443 0.05879116819887738
# Cell_Texture_SNCA_Entropy_090 0.235801 0.0580991793201404
# Cell_Texture_SNCA_Entropy_135 0.243962 0.05903035253463559
# Cell_Texture_SNCA_InfoMeasuresOfCorr1_000 -0.48 0.04623864247271491
# Cell_Texture_SNCA_InfoMeasuresOfCorr1_045 -0.41864 0.038811449013702266
# Cell_Texture_SNCA_InfoMeasuresOfCorr1_090 -0.478085 0.04663834641695446
# Cell_Texture_SNCA_InfoMeasuresOfCorr1_135 -0.418782 0.03984782375806263
# Cell_Texture_SNCA_InfoMeasuresOfCorr2_000 0.363619 0.03299559897039344
# Cell_Texture_SNCA_InfoMeasuresOfCorr2_045 0.341179 0.033029586788116044
# Cell_Texture_SNCA_InfoMeasuresOfCorr2_090 0.362673 0.03285014206797275
# Cell_Texture_SNCA_InfoMeasuresOfCorr2_135 0.339076 0.03261071187468831
# Cell_Texture_SNCA_InverseDiffMoment_000 0.960211 0.018160352536172677
# Cell_Texture_SNCA_InverseDiffMoment_045 0.95439 0.01955274541283368
# Cell_Texture_SNCA_InverseDiffMoment_090 0.96041 0.018171624874858957
# Cell_Texture_SNCA_InverseDiffMoment_135 0.953759 0.019672192243137713
# Cell_Texture_SNCA_SumAverage_000 0.502395 0.5662838318979062
# Cell_Texture_SNCA_SumAverage_045 0.502564 0.5663944719577095
# Cell_Texture_SNCA_SumAverage_090 0.502407 0.566301099647756
# Cell_Texture_SNCA_SumAverage_135 0.502563 0.5663942666080486
# Cell_Texture_SNCA_SumEntropy_000 0.211095 0.05173062910707493
# Cell_Texture_SNCA_SumEntropy_045 0.217988 0.051949838393585454
# Cell_Texture_SNCA_SumEntropy_090 0.211153 0.05176106721000633
# Cell_Texture_SNCA_SumEntropy_135 0.21785 0.05206125280111068
# Cell_Texture_SNCA_SumOfSquares_000 3.60533 5.0575921882892505
# Cell_Texture_SNCA_SumOfSquares_045 3.6063 5.059531797972601
# Cell_Texture_SNCA_SumOfSquares_090 3.60865 5.058838167483106
# Cell_Texture_SNCA_SumOfSquares_135 3.6063 5.059527955338062
# Cell_Texture_SNCA_SumVariance_000 13.2328 18.651572575230965
# Cell_Texture_SNCA_SumVariance_045 12.6957 18.220161675283663
# Cell_Texture_SNCA_SumVariance_090 13.1632 18.668347986601304
# Cell_Texture_SNCA_SumVariance_135 13.0639 18.216436789871132
# Cytoplasm_Intensity_MeanIntensity_SNCA 679.61 240.22679563671528
# Cytoplasm_MAP2_SNCA_Intensity_MeanIntensity_SNCA 731.111 798.6257774887475
# Cytoplasm_SurfacePerNuclei_SNCA 383.988 187.07926065071226
# Cytoplasm_SurfacePerNuclei_TH_SNCA 512.427 113.87926210053263
# Cytoplasm_Surface_TotalSurface_SNCA 333552.0 195671.89598790367
# IndividualCell_Intensity_MeanIntensity_SNCA 692.587 51.169499855282154
# IndividualCell_Intensity_RadialProfile_InterceptFit_SNCA 826.918 115.13989414146378
# IndividualCell_Intensity_RadialProfile_MaxSlope_SNCA -4.97053 3.128463203080844
# IndividualCell_Intensity_RadialProfile_Maximum_SNCA 1663.21 233.057682558182
# IndividualCell_Intensity_RadialProfile_MeanCoeffVar_SNCA 30.5611 8.27645654274525
# IndividualCell_Intensity_RadialProfile_MeanGradient_SNCA -4.29367 2.624342270945187
# IndividualCell_Intensity_RadialProfile_Mean_SNCA 881.468 89.2185967736395
# IndividualCell_Intensity_RadialProfile_Median_SNCA 1082.6 125.85347803745216
# IndividualCell_Intensity_RadialProfile_Q1_SNCA 729.176 60.59829618829937
# IndividualCell_Intensity_RadialProfile_Q3_SNCA 1385.53 181.78648139738453
# IndividualCell_Intensity_RadialProfile_SlopeFit_SNCA -4.42619 2.698141252490802
# IndividualCell_Intensity_RadialProfile_StdCoeffVar_SNCA 24.9329 19.444344002048933
# IndividualCell_Intensity_RadialProfile_Std_SNCA 198.911 39.78831393353488
# IndividualCell_Intensity_SumIntensity_SNCA 4539110.0 2488197.157120391
# IndividualCell_Surface_MeanSurface_SNCA 6004.87 2824.3229185499254
# Membrane_Intensity_MeanIntensity_MAP2 450.451 23.666517580034935
# Membrane_Intensity_MeanIntensity_SNCA 748.015 61.58971682082077
# Membrane_Intensity_MeanIntensity_TH 292.622 52.06912641671674
# Membrane_Surface_SurfacePerNuclei_MAP2 464.505 188.452292337662
# Membrane_Surface_SurfacePerNuclei_SNCA 67.201 30.511642304618185
# Membrane_Surface_SurfacePerNuclei_TH 225.338 82.11065434708449
# Nuclei_Living_Ratio_MAP2 0.205669 0.04228723239641983
# Nuclei_Living_Ratio_MAP2_SNCA 0.182515 0.038590253935687976
# Nuclei_Living_Ratio_TH_SNCA 0.251975 0.07778862488922582
# Nuclei_Surface_MeanArea 1091.77 32.49993317287632
# Cell_Correlation_MAP2_SNCA 0.254453 0.06972738442429127
# Cell_Correlation_TH_SNCA 0.0720255 0.0327690117403971
# Cell_Correlation_VanSteelselsMeanX_TH_SNCA 25.3763 3.720850686836487
# Cell_Correlation_VanSteelselsMeanY_TH_SNCA 24.8691 3.0943003045453317
# Cell_Correlation_VanSteelselsSigmaX_TH_SNCA 4.57787 2.518303374739622
# Cell_Correlation_VanSteelselsSigmaY_TH_SNCA 4.46406 2.329725618046182
# Cell_Intensity_MeanIntensity_MAP2 658.297 35.50806084531355
# Cell_Intensity_MeanIntensity_SNCA 730.146 46.69767205484896
# Cell_Intensity_MeanIntensity_TH 390.961 54.49745227741284
# Cell_Intensity_SumIntensityPerNuclei_SNCA 1319940.0 146228.48437471723
# Cell_MAP2_SNCA_Intensity_MeanIntensity_SNCA 786.483 100.91391492320481
# Cell_Neurites_BranchingPointsPerNuclei_MAP2 1.93617 0.2878797084677016
# Cell_Neurites_BranchingPointsPerNuclei_TH 1.48539 0.21642985814786111
# Cell_Neurites_LengthPerNuclei_MAP2 283.676 29.45691033147608
# Cell_Neurites_LengthPerNuclei_TH 212.937 26.251617643156564
# Cell_Neurites_Length_MAP2 107207.0 20227.836388695214
# Cell_Neurites_Length_TH 107039.0 20120.318508254284
# Cell_SurfacePerNuclei_MAP2 4440.14 324.8820085396885
# Cell_SurfacePerNuclei_MAP2_SNCA 1667.59 125.67848858628645
# Cell_SurfacePerNuclei_SNCA 1772.22 146.33921249334824
# Cell_SurfacePerNuclei_TH 4470.54 289.6634068657084
# Cell_SurfacePerNuclei_TH_SNCA 1656.58 119.1405201409197
# Cell_Surface_RatioSurface_TH_SNCA 0.655924 0.093531746471646
# Cell_TH_SNCA_Intensity_MeanIntensity_SNCA 760.534 87.098265674106
# Cell_TH_SNCA_Intensity_MeanIntensity_TH 329.562 34.753129216015445
# Cell_TH_SNCA_Intensity_SumIntensityPerNuclei_SNCA 1281650.0 166749.03160037313
# Cell_Texture_SNCA_AngularSecondMoment_000 0.871411 0.023632333638380555
# Cell_Texture_SNCA_AngularSecondMoment_045 0.866597 0.024263988730759002
# Cell_Texture_SNCA_AngularSecondMoment_090 0.871346 0.02360244445361444
# Cell_Texture_SNCA_AngularSecondMoment_135 0.866708 0.024255231333159176
# Cell_Texture_SNCA_Contrast_000 1.04846 1.5873862102211278
# Cell_Texture_SNCA_Contrast_045 1.41706 2.0936507143766523
# Cell_Texture_SNCA_Contrast_090 0.957146 1.5705588334711267
# Cell_Texture_SNCA_Contrast_135 1.43702 2.088941795506021
# Cell_Texture_SNCA_Correlation_000 719.625 1027.7021704845424
# Cell_Texture_SNCA_Correlation_045 667.704 976.6739237198726
# Cell_Texture_SNCA_Correlation_090 711.784 1030.1378208719236
# Cell_Texture_SNCA_Correlation_135 668.858 977.8119960099929
# Cell_Texture_SNCA_DifferenceEntropy_000 0.0789864 0.012348301625806343
# Cell_Texture_SNCA_DifferenceEntropy_045 0.0909071 0.01373952366229313
# Cell_Texture_SNCA_DifferenceEntropy_090 0.0781164 0.012264771911153596
# Cell_Texture_SNCA_DifferenceEntropy_135 0.0902613 0.013670626455824605
# Cell_Texture_SNCA_DifferenceVariance_000 9.33e-07 4.785816637616707e-07
# Cell_Texture_SNCA_DifferenceVariance_045 1.17e-06 5.813881267755265e-07
# Cell_Texture_SNCA_DifferenceVariance_090 9.38e-07 4.787045585744929e-07
# Cell_Texture_SNCA_DifferenceVariance_135 1.16e-06 5.785982088538548e-07
# Cell_Texture_SNCA_Entropy_000 0.177177 0.027447371055892077
# Cell_Texture_SNCA_Entropy_045 0.185001 0.028522951008972872
# Cell_Texture_SNCA_Entropy_090 0.176727 0.02739493652794172
# Cell_Texture_SNCA_Entropy_135 0.184824 0.028500259727452786
# Cell_Texture_SNCA_InfoMeasuresOfCorr1_000 -0.515142 0.021547331083881363
# Cell_Texture_SNCA_InfoMeasuresOfCorr1_045 -0.447857 0.02041001746996476
# Cell_Texture_SNCA_InfoMeasuresOfCorr1_090 -0.516506 0.021696335131736483
# Cell_Texture_SNCA_InfoMeasuresOfCorr1_135 -0.448053 0.019893146144767216
# Cell_Texture_SNCA_InfoMeasuresOfCorr2_000 0.340269 0.022419130095935685
# Cell_Texture_SNCA_InfoMeasuresOfCorr2_045 0.318793 0.021276410481703804
# Cell_Texture_SNCA_InfoMeasuresOfCorr2_090 0.3409 0.02257653523101265
# Cell_Texture_SNCA_InfoMeasuresOfCorr2_135 0.319306 0.021294779546521102
# Cell_Texture_SNCA_InverseDiffMoment_000 0.972636 0.010143856738700958
# Cell_Texture_SNCA_InverseDiffMoment_045 0.967838 0.011395922504677818
# Cell_Texture_SNCA_InverseDiffMoment_090 0.972796 0.010112888322479054
# Cell_Texture_SNCA_InverseDiffMoment_135 0.967801 0.011353216522053212
# Cell_Texture_SNCA_SumAverage_000 0.491531 0.4132550595014122
# Cell_Texture_SNCA_SumAverage_045 0.491672 0.41331001193491534
# Cell_Texture_SNCA_SumAverage_090 0.491459 0.4132255572696453
# Cell_Texture_SNCA_SumAverage_135 0.491672 0.4133100465791911
# Cell_Texture_SNCA_SumEntropy_000 0.159914 0.02452533214908481
# Cell_Texture_SNCA_SumEntropy_045 0.164693 0.02501720475937754
# Cell_Texture_SNCA_SumEntropy_090 0.160075 0.024495035783817277
# Cell_Texture_SNCA_SumEntropy_135 0.16466 0.02500588866431799
# Cell_Texture_SNCA_SumOfSquares_000 2.7774 4.055195384146089
# Cell_Texture_SNCA_SumOfSquares_045 2.77923 4.056121747621831
# Cell_Texture_SNCA_SumOfSquares_090 2.7777 4.055479730319393
# Cell_Texture_SNCA_SumOfSquares_135 2.77923 4.0561253436898
# Cell_Texture_SNCA_SumVariance_000 10.3063 15.06979526869831
# Cell_Texture_SNCA_SumVariance_045 9.94459 14.713286013468506
# Cell_Texture_SNCA_SumVariance_090 10.2402 15.086502585769765
# Cell_Texture_SNCA_SumVariance_135 9.95239 14.721774724081222
# Cytoplasm_Intensity_MeanIntensity_SNCA 740.955 270.49373812551954
# Cytoplasm_MAP2_SNCA_Intensity_MeanIntensity_SNCA 750.686 573.49155899362
# Cytoplasm_SurfacePerNuclei_SNCA 251.942 56.53249798536295
# Cytoplasm_SurfacePerNuclei_TH_SNCA 262.406 59.7729992671905
# Cytoplasm_Surface_TotalSurface_SNCA 211075.0 48091.00067173575
# IndividualCell_Intensity_MeanIntensity_SNCA 680.171 48.10377063438121
# IndividualCell_Intensity_RadialProfile_InterceptFit_SNCA 792.104 73.28838122923078
# IndividualCell_Intensity_RadialProfile_MaxSlope_SNCA -4.51317 2.582032821824916
# IndividualCell_Intensity_RadialProfile_Maximum_SNCA 1544.67 208.19903289560855
# IndividualCell_Intensity_RadialProfile_MeanCoeffVar_SNCA 28.7589 45.835965919040675
# IndividualCell_Intensity_RadialProfile_MeanGradient_SNCA -4.12433 1.943252743046293
# IndividualCell_Intensity_RadialProfile_Mean_SNCA 842.062 81.3470556438889
# IndividualCell_Intensity_RadialProfile_Median_SNCA 1018.58 112.42880775306577
# IndividualCell_Intensity_RadialProfile_Q1_SNCA 698.353 54.13332977286689
# IndividualCell_Intensity_RadialProfile_Q3_SNCA 1293.06 162.39539652063212
# IndividualCell_Intensity_RadialProfile_SlopeFit_SNCA -4.23555 1.9652786803470517
# IndividualCell_Intensity_RadialProfile_StdCoeffVar_SNCA 24.6242 210.64781803055598
# IndividualCell_Intensity_RadialProfile_Std_SNCA 176.364 37.86413160437724
# IndividualCell_Intensity_SumIntensity_SNCA 3287840.0 956417.3612883452
# IndividualCell_Surface_MeanSurface_SNCA 4367.69 1016.9755489232089
# Membrane_Intensity_MeanIntensity_MAP2 499.627 20.364350046071525
# Membrane_Intensity_MeanIntensity_SNCA 692.501 52.204249241091055
# Membrane_Intensity_MeanIntensity_TH 292.201 43.396718054923106
# Membrane_Surface_SurfacePerNuclei_MAP2 539.499 162.7855142626094
# Membrane_Surface_SurfacePerNuclei_SNCA 84.3322 29.592130214859825
# Membrane_Surface_SurfacePerNuclei_TH 252.63 84.23806324177107
# Nuclei_Living_Ratio_MAP2 0.317377 0.048240405407111685
# Nuclei_Living_Ratio_MAP2_SNCA 0.265797 0.04236065821420416
# Nuclei_Living_Ratio_TH_SNCA 0.302128 0.04400169650006992
# Nuclei_Surface_MeanArea 1078.62 32.022936668720575
# [DATA NORMALIZED]
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# Mut;DMSO v.s. WT;DMSO: Mann-Whitney-Wilcoxon test two-sided, P_val=9.233e-22 U_stat=3.922e+03
# WT;DMSO v.s. WT;DMSO_p1: Mann-Whitney-Wilcoxon test two-sided, P_val=8.759e-10 U_stat=3.700e+02
# Mut;DMSO v.s. Mut;DMSO_p1: Mann-Whitney-Wilcoxon test two-sided, P_val=1.740e-01 U_stat=3.377e+03
# WT;DMSO v.s. WT;DMSO_p2: Mann-Whitney-Wilcoxon test two-sided, P_val=1.734e-01 U_stat=1.650e+03
# Mut;DMSO v.s. Mut;DMSO_p2: Mann-Whitney-Wilcoxon test two-sided, P_val=5.990e-01 U_stat=2.914e+03

# %% [markdown]
# ### SVM Analysis (with feature selection by previous Pearson Correlations Threshold)
# Selection of hyperparameters by SciKitLearn's grid search using cross validation.

# %%
train_set_proportion = 0.8

x_train_grid, x_test_grid, y_train_grid, y_test_grid = train_test_split(df_X_without_correlated[subset_columns], Y_training, train_size=train_set_proportion, stratify=Y_training, random_state=100)

# Set the parameters by cross-validation

tested_C = list(np.linspace(0.05, 1., 20))
tested_C.append(1.5)
tested_C.append(2)
tested_C.append(3)
tested_C.append(5)
tested_C.append(10)

tuned_parameters = [
    {"kernel": ["rbf"], "gamma": ['scale'], "C": tested_C}, # np.logspace(-2, 1, 100)
    {"kernel": ["poly"], "gamma": ['scale'], "C": tested_C},
    {"kernel": ["linear"], "C": tested_C},
]

best_C = []

clf = SVC()

for parameters in tuned_parameters:
    
    cv = GridSearchCV(clf, param_grid=parameters, scoring="f1", 
                      cv=StratifiedShuffleSplit(n_splits=4, test_size=1.-train_set_proportion, random_state=0))
    cv.fit(df_X_without_correlated[subset_columns], Y_training)
    C = cv.best_estimator_
    best_C.append(C)

    print(parameters)
    print(C)

print()
print('GridSearchCV Optimized for rbf kernel :')
print("\'kernel\': [\'rbf\'], \'gamma\': [\'scale\'], \'C\': [",best_C[0].C,"]")
print()

# scores = ["precision", "recall"]

# for score in scores:
#     print("# Tuning hyper-parameters for %s" % score)
#     print()

#     clf = GridSearchCV(SVC(), tuned_parameters, scoring="%s_macro" % score)
#     clf.fit(x_train_grid, y_train_grid)

#     print("Best parameters set found on development set:")
#     print()
#     print(clf.best_params_)
#     print()
#     print("Grid scores on development set:")
#     print()
#     means = clf.cv_results_["mean_test_score"]
#     stds = clf.cv_results_["std_test_score"]
#     for mean, std, params in zip(means, stds, clf.cv_results_["params"]):
#         print("%0.3f (+/-%0.03f) for %r" % (mean, std * 2, params))
#     print()

#     print("Detailed classification report:")
#     print()
#     print("The model is trained on the full development set.")
#     print("The scores are computed on the full evaluation set.")
#     print()
#     y_true_grid, y_pred_grid = y_test_grid, clf.predict(x_test_grid)
#     print(classification_report(y_true_grid, y_pred_grid))
#     print()
# Out:
# {'kernel': ['rbf'], 'gamma': ['scale'], 'C': [0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.39999999999999997, 0.44999999999999996, 0.49999999999999994, 0.5499999999999999, 0.6, 0.65, 0.7, 0.75, 0.7999999999999999, 0.85, 0.9, 0.95, 1.0, 1.5, 2, 3, 5, 10]}
# SVC(C=2)
# {'kernel': ['poly'], 'gamma': ['scale'], 'C': [0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.39999999999999997, 0.44999999999999996, 0.49999999999999994, 0.5499999999999999, 0.6, 0.65, 0.7, 0.75, 0.7999999999999999, 0.85, 0.9, 0.95, 1.0, 1.5, 2, 3, 5, 10]}
# SVC(C=5, kernel='poly')
# {'kernel': ['linear'], 'C': [0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.39999999999999997, 0.44999999999999996, 0.49999999999999994, 0.5499999999999999, 0.6, 0.65, 0.7, 0.75, 0.7999999999999999, 0.85, 0.9, 0.95, 1.0, 1.5, 2, 3, 5, 10]}
# SVC(C=0.05, kernel='linear')
#
# GridSearchCV Optimized for rbf kernel :
# 'kernel': ['rbf'], 'gamma': ['scale'], 'C': [ 2 ]

# %% [markdown]
# ### SVM classifier with tuned hyperparameters

# %%
output_path_all = output_path+'/SVM_features_after_correlations/'

if not os.path.exists(output_path_all):
	os.makedirs(output_path_all, exist_ok=True)

C = best_C[0].C # clf.best_params_['C']

svm_analysis = SVC(probability=True, kernel='rbf', C=C, gamma='scale')
svm_analysis.fit(x_train, y_train)

SVM_train = svm_analysis.predict_proba(x_train)
SVM_test = svm_analysis.predict_proba(x_test)

binwidth = 0.05
bins = np.arange(0, 1. + binwidth, binwidth)

with sns.axes_style("white"), sns.plotting_context("talk"):
	fig, axes = plt.subplots(figsize=(16, 6), nrows=1, ncols=2)
	axes[0].hist(SVM_train[y_train==0,0], label=ctrl_neg, bins=bins)
	axes[0].hist(SVM_train[y_train==1,0], label=ctrl_pos, bins=bins)
	axes[0].set_title('SVM Training Set')
	axes[1].hist(SVM_test[y_test==0,0], label=ctrl_neg, bins=bins)
	axes[1].hist(SVM_test[y_test==1,0], label=ctrl_pos, bins=bins)
	axes[1].set_title('SVM Testing Set')
	plt.tight_layout()
	sns.despine()
	plt.savefig(output_path_all+'SVM_training_test_set_after_correlations.pdf', bbox_inches='tight')
	plt.show()

from sklearn.model_selection import cross_val_score
scores = cross_val_score(svm_analysis, X_subset, Y_training, cv=10)
print("Cross Valid Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std()))

SVM_dmso_and_cpds_training = svm_analysis.predict_proba(X_all_cpds_subset)
SVM_dmso_and_cpds_testing = svm_analysis.predict_proba(X_testing_subset)

X_all_cpds_svm1 = X_all_cpds_subset.copy()

X_all_cpds_svm1['SVM_Projection'] = SVM_dmso_and_cpds_training[:,0]
X_all_cpds_svm1['tags'] = Y_all_cpds_training

X_all_cpds_subset_svm2 = X_testing_subset.copy()
X_all_cpds_subset_svm2['SVM_Projection'] = SVM_dmso_and_cpds_testing[:,0]
X_all_cpds_subset_svm2['tags'] = Y_testing

X_all_cpds_svm = pd.concat([X_all_cpds_svm1, X_all_cpds_subset_svm2])

X_all_cpds_svm = X_all_cpds_svm[X_all_cpds_svm.tags.str.contains('DMSO')]

list_z_train, list_z_test = cross_valid_z_prime_svm(svm_analysis, X_subset, Y_training, 25, train_set_proportion, output_path_all)

xpoints = range(len(list_z_test))

training = ['Training'] * len(list_z_train)
testing = ['Testing'] * len(list_z_test)

training_df = pd.DataFrame(
    {'Y': list_z_train,
     'X': xpoints,
     'Hue': training
    })

testing_df = pd.DataFrame(
    {'Y': list_z_test,
     'X': xpoints,
     'Hue': testing
    })

test_train = training_df.append(testing_df).reset_index(drop=True)

sns.set_context("talk")                
ax = sns.lineplot(data=test_train, x='X', y='Y', hue='Hue')
ax.set(xlabel='Cross Validation Dataset', ylabel='Z factor')
plt.hlines(np.mean(list_z_train), 0, len(list_z_train)-1, colors=sns.color_palette()[0], linestyles='dashed')
plt.hlines(np.mean(list_z_test), 0, len(list_z_test)-1, colors=sns.color_palette()[1], linestyles='dashed')
sns.despine()
# Put the legend out of the figure and remove title
handles, labels = ax.get_legend_handles_labels()
ax.legend(['Z Factor Training Set, Avg = '+"%.2f" % np.mean(list_z_train), 
           'Z Factor Testing Set, Avg = '+"%.2f" % np.mean(list_z_test)], handles=handles[2:], labels=labels[2:], bbox_to_anchor=(1.02, 0.3), loc=3, borderaxespad=0., 
           frameon=False)
plt.savefig(output_path_all+'SVM_CV_ZFactor_after_correlations.pdf', bbox_inches='tight')
plt.show()

X_all_cpds_pl_well = X_all_cpds_subset.reset_index()
plates = X_all_cpds_pl_well['Plate']

# list_tags_plates = []
# for i in range(len(Y_all_cpds_p3)):
#     list_tags_plates.append(Y_all_cpds_p3[i]+'_'+plates[i])
    
# X_all_cpds_svm['tags_plate'] = list_tags_plates

# sns.set_context("talk")

# medianline_X_all_cpds_svm = X_all_cpds_svm[(X_all_cpds_svm['tags'].str.contains('Mut;DMSO'))]
# median = medianline_X_all_cpds_svm['SVM_Projection'].median()
# median_std = median-(3*(medianline_X_all_cpds_svm['SVM_Projection'].std()))
# 
# # Hit rate calculation and plotting
# PEP005_X_all_cpds_svm = X_all_cpds_svm[(X_all_cpds_svm['tags'].str.contains('Mut;PEP005'))]
# PEP005_X_all_cpds_svm_thresh = PEP005_X_all_cpds_svm.loc[PEP005_X_all_cpds_svm['SVM_Projection'] < median_std]
# Prostratin_X_all_cpds_svm = X_all_cpds_svm[(X_all_cpds_svm['tags'].str.contains('Mut;Prostratin'))]
# Prostratin_X_all_cpds_svm_thresh = Prostratin_X_all_cpds_svm.loc[Prostratin_X_all_cpds_svm['SVM_Projection'] < median_std]
# DMSO_X_all_cpds_svm = X_all_cpds_svm[(X_all_cpds_svm['tags'].str.contains('Mut;DMSO'))]
# DMSO_X_all_cpds_svm_thresh = DMSO_X_all_cpds_svm.loc[DMSO_X_all_cpds_svm['SVM_Projection'] < median_std]

# hit_rate_PEP005 = PEP005_X_all_cpds_svm_thresh['SVM_Projection'].count()/PEP005_X_all_cpds_svm['SVM_Projection'].count()
# hit_rate_Prostratin = Prostratin_X_all_cpds_svm_thresh['SVM_Projection'].count()/Prostratin_X_all_cpds_svm['SVM_Projection'].count()
# hit_rate_DMSO = DMSO_X_all_cpds_svm_thresh['SVM_Projection'].count()/DMSO_X_all_cpds_svm['SVM_Projection'].count()

# print('Hit rate PEP005: ', hit_rate_PEP005)
# print('Hit rate Prostratin: ', hit_rate_Prostratin)
# print('Hit rate DMSO: ', hit_rate_DMSO)

# d = {'Compound': ['DMSO', 'PEP005', 'Prostratin'], 'Hit rate': [hit_rate_DMSO, hit_rate_PEP005, hit_rate_Prostratin]}
# df_hit_rate = pd.DataFrame(data=d)

# f, ax = plt.subplots(figsize=(2.5,5))
# ax = sns.barplot(x='Compound', y='Hit rate', data=df_hit_rate)
# sns.despine()
# ax.set_xlabel(None)
# ax.set_ylabel('> DMSO median + 3x SD \n (fraction of wells)')
# ax.set_title('Hit wells (fraction)')
# ax.set_xticklabels(ax.get_xticklabels(),rotation=45, ha='right', rotation_mode="anchor")
# plt.savefig(output_path_all+'Hit_rate.pdf', bbox_inches='tight')
# plt.show()                                    

fig, ax = plt.subplots(figsize=(8,4))
ax = sns.boxplot(x='tags', y='SVM_Projection', data=X_all_cpds_svm, width=0.7, showfliers=False, zorder=1,
                 notch=1, bootstrap = 1000, order=order)
# Transparancy of boxplot filling color
for patch in ax.artists:
    r, g, b, a = patch.get_facecolor()
    patch.set_facecolor((r, g, b, 0))
s = sns.stripplot(x='tags', y='SVM_Projection', data=X_all_cpds_svm, size=10, alpha=0.3, jitter=0.2, zorder=0, order=order)
from statannot import add_stat_annotation

add_stat_annotation(s, data=X_all_cpds_svm, x='tags', y='SVM_Projection', box_pairs=box_pairs,
               loc='outside', verbose=1, test='Mann-Whitney', comparisons_correction=None,
               perform_stat_test=True, order=order,
               color='0.2', linewidth=1.5,
               fontsize=20)
s.set(xlabel=None)
s.set_xticklabels(s.get_xticklabels(),rotation=45, ha='right', rotation_mode="anchor")
sns.despine()
plt.savefig(output_path_all+"SVM_Projection_All_Conditions_after_correlations.pdf", bbox_inches='tight')
plt.show()
# Out:
# Cross Valid Accuracy: 0.99 (+/- 0.03)
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# WT;DMSO v.s. Mut;DMSO: Mann-Whitney-Wilcoxon test two-sided, P_val=9.233e-22 U_stat=0.000e+00
# WT;DMSO v.s. WT;DMSO_p1: Mann-Whitney-Wilcoxon test two-sided, P_val=1.484e-13 U_stat=1.850e+02
# Mut;DMSO v.s. Mut;DMSO_p1: Mann-Whitney-Wilcoxon test two-sided, P_val=3.184e-01 U_stat=3.276e+03
# WT;DMSO v.s. WT;DMSO_p2: Mann-Whitney-Wilcoxon test two-sided, P_val=4.569e-04 U_stat=8.680e+02
# Mut;DMSO v.s. Mut;DMSO_p2: Mann-Whitney-Wilcoxon test two-sided, P_val=1.209e-01 U_stat=3.184e+03

# %% [markdown]
# ### Function to calculate Z Factor :

# %%
def get_acc_zfactor(lda_analysis, x_train, y_train, x_test, y_test):

    lda_analysis.fit(x_train, y_train)
    
    accuracy_train = lda_analysis.score(x_train, y_train)
    accuracy_test = lda_analysis.score(x_test, y_test)

    x_neg_train = lda_analysis.transform(x_train[y_train == 0])
    x_pos_train = lda_analysis.transform(x_train[y_train == 1])

    z_train = 1.0 - 3.0 * (np.std(x_neg_train) + np.std(x_pos_train)) / np.abs(
        np.mean(x_neg_train) - np.mean(x_pos_train))

    x_neg_test = lda_analysis.transform(x_test[y_test == 0])
    x_pos_test = lda_analysis.transform(x_test[y_test == 1])

    z_test = 1.0 - 3.0 * (np.std(x_neg_test) + np.std(x_pos_test)) / np.abs(np.mean(x_neg_test) - np.mean(x_pos_test))

    return accuracy_train, accuracy_test, z_train, z_test

# %% [markdown]
# ### LOO Features, LDA :

# %%
def LOO_features_LDA(X, Y, train_set_proportion = 0.8, shrink = 'auto', seed=100):

    lda_analysis = LDA(solver='eigen', n_components=1, shrinkage=shrink)

    x_train, x_test, y_train, y_test = train_test_split(X, Y, train_size=train_set_proportion, stratify=Y, random_state=seed)

    accuracy_train, accuracy_test, z_train, z_test = get_acc_zfactor(lda_analysis, x_train, y_train, x_test, y_test)

    list_feature_removed = []
    list_acc_train = []
    list_acc_test = []
    list_z_train = []
    list_z_test = []

    for f in x_train.columns:

        x_train_loo = x_train.drop([f], axis=1)
        x_test_loo = x_test.drop([f], axis=1)

        accuracy_train_loo, accuracy_test_loo, z_train_loo, z_test_loo = get_acc_zfactor(lda_analysis, x_train_loo, y_train, x_test_loo, y_test)

        list_feature_removed.append(f)
        list_acc_train.append(accuracy_train_loo)
        list_acc_test.append(accuracy_test_loo)
        list_z_train.append(z_train_loo)
        list_z_test.append(z_test_loo)
    
    return accuracy_train, accuracy_test, z_train, z_test, list_feature_removed, list_acc_train, list_acc_test, list_z_train, list_z_test

# %% [markdown]
# ### Leave One Out based on ZFactor, LDA
# Computes the ZFactor shift removing one feature to the SVM classification.

# %%
output_path_loo = output_path+'/LOO_Results/'

if not os.path.exists(output_path_loo):
	os.makedirs(output_path_loo, exist_ok=True)

XLOO = X_subset.copy()

CV = 3

lacc_train, lacc_test, lztrain, lztest, llfeature_removed, llacc_train, llacc_test, llz_train, llz_test = [], [], [], [], [], [], [], [], []

for crossval in range(CV):
        acc_train, acc_test, ztrain, ztest, lfeature_removed, lacc_train, lacc_test, lz_train, lz_test = LOO_features_LDA(XLOO, Y_training, train_set_proportion = 0.8, shrink = 'auto', seed=crossval)
        lacc_train.append(acc_train)
        lacc_test.append(acc_test)
        lztrain.append(ztrain)
        lztest.append(ztest)
        llfeature_removed.append(lfeature_removed)
        llacc_train.append(lacc_train)
        llacc_test.append(lacc_test)
        llz_train.append(lz_train)
        llz_test.append(lz_test)


vec_cv_ztrain = []
vec_cv_ztest = []


for i, val in enumerate(lztrain):
        vec_cv_ztrain.append(-np.array(llz_train[i]) + lztrain[i])
        vec_cv_ztest.append(-np.array(llz_test[i]) + lztest[i])

df_loo_lda = pd.DataFrame()

# display(vec_cv_ztrain)

df_loo_lda['Feature'] = lfeature_removed
df_loo_lda['Diff_ZTrain'] = np.mean(vec_cv_ztrain, axis=0)
df_loo_lda['Diff_ZTest'] = np.mean(vec_cv_ztest, axis=0)
df_loo_lda['std_ZTrain'] = np.std(vec_cv_ztrain, axis=0)
df_loo_lda['std_ZTest'] = np.std(vec_cv_ztest, axis=0)

# display(df_loo_lda['Diff_ZTrain'])
# display(df_loo_lda['std_ZTrain'])

df_loo_lda.sort_values(['Diff_ZTrain'], inplace=True)

df_feature_ranking_loo_lda_pl3 = pd.DataFrame()
l_feat = []
l_rank = []

for i, f in enumerate(df_loo_lda['Feature']):
    l_rank.append(i+1)
    l_feat.append(f)

df_feature_ranking_loo_lda_pl3["Feature"] = l_feat
df_feature_ranking_loo_lda_pl3["Ranking_3"] = l_rank

df_feature_ranking_loo_lda_pl3.to_csv("feat_ranking_loo_lda_pl3.csv", index=None)

my_cmap_red = plt.get_cmap("Reds")
my_cmap_blue = plt.get_cmap("Blues")

my_colors = []
for value in df_loo_lda['Diff_ZTrain']:
        if value < 0:
                my_colors.append(my_cmap_red(.5+np.abs(0.25*value/df_loo_lda['Diff_ZTrain'].min())))
        else:
                my_colors.append(my_cmap_blue(.5+np.abs(0.25*value/df_loo_lda['Diff_ZTrain'].max())))

f, ax = plt.subplots(figsize=(10,20))

ax.barh(range(len(df_loo_lda)),
        df_loo_lda['Diff_ZTrain'],
        align='center', edgecolor='k', xerr=df_loo_lda['std_ZTrain'], color=my_colors)

ax.set_yticks(range(len(df_loo_lda)))
ax.set_yticklabels(df_loo_lda['Feature'])
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

plt.xlabel('ZFactor Shift')
plt.title('Feature Importances : LOO ZFactor Train Set')
plt.savefig(output_path_loo+"LOO_LDA_Train_Set.pdf", bbox_inches='tight')
plt.show()

df_loo_lda.sort_values(['Diff_ZTest'], inplace=True)

my_cmap_red = plt.get_cmap("Reds")
my_cmap_blue = plt.get_cmap("Blues")

my_colors = []
for value in df_loo_lda['Diff_ZTest']:
        if value < 0:
                my_colors.append(my_cmap_red(.5+np.abs(0.25*value/df_loo_lda['Diff_ZTest'].min())))
        else:
                my_colors.append(my_cmap_blue(.5+np.abs(0.25*value/df_loo_lda['Diff_ZTest'].max())))

f, ax = plt.subplots(figsize=(10,20))

ax.barh(range(len(df_loo_lda)),
        df_loo_lda['Diff_ZTest'],
        align='center', edgecolor='k', xerr=df_loo_lda['std_ZTest'], color=my_colors)

ax.set_yticks(range(len(df_loo_lda)))
ax.set_yticklabels(df_loo_lda['Feature'])
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

plt.xlabel('ZFactor Shift');
plt.title('Feature Importances : LOO ZFactor Test Set')
plt.savefig(output_path_loo+"LOO_LDA_Test_Set.pdf", bbox_inches='tight')
plt.show()

# %%
def get_acc_zfactor_svm(svm_analysis, x_train, y_train, x_test, y_test):

    svm_analysis.fit(x_train, y_train)
    
    accuracy_train = svm_analysis.score(x_train, y_train)
    accuracy_test = svm_analysis.score(x_test, y_test)

    x_neg_train = svm_analysis.predict_proba(x_train[y_train == 0])[:,0]
    x_pos_train = svm_analysis.predict_proba(x_train[y_train == 1])[:,0]

    z_train = 1.0 - 3.0 * (np.std(x_neg_train) + np.std(x_pos_train)) / np.abs(
        np.mean(x_neg_train) - np.mean(x_pos_train))

    x_neg_test = svm_analysis.predict_proba(x_test[y_test == 0])[:,0]
    x_pos_test = svm_analysis.predict_proba(x_test[y_test == 1])[:,0]

    z_test = 1.0 - 3.0 * (np.std(x_neg_test) + np.std(x_pos_test)) / np.abs(np.mean(x_neg_test) - np.mean(x_pos_test))

    # print(z_train, z_test)

    return accuracy_train, accuracy_test, z_train, z_test

# %% [markdown]
# ### LOO Features, SVM :

# %%
def LOO_features_SVM(X, Y, train_set_proportion, C, seed=100):

    svm_analysis = SVC(probability=True, kernel='rbf', C=C, gamma='scale')
    
    x_train, x_test, y_train, y_test = train_test_split(X, Y, train_size=train_set_proportion, stratify=Y, random_state=seed)

    accuracy_train, accuracy_test, z_train, z_test = get_acc_zfactor_svm(svm_analysis, x_train, y_train, x_test, y_test)

    list_feature_removed = []
    list_acc_train = []
    list_acc_test = []
    list_z_train = []
    list_z_test = []

    for f in x_train.columns:

        x_train_loo = x_train.drop([f], axis=1)
        x_test_loo = x_test.drop([f], axis=1)

        accuracy_train_loo, accuracy_test_loo, z_train_loo, z_test_loo = get_acc_zfactor_svm(svm_analysis, x_train_loo, y_train, x_test_loo, y_test)

        list_feature_removed.append(f)
        list_acc_train.append(accuracy_train_loo)
        list_acc_test.append(accuracy_test_loo)
        list_z_train.append(z_train_loo)
        list_z_test.append(z_test_loo)
    
    return accuracy_train, accuracy_test, z_train, z_test, list_feature_removed, list_acc_train, list_acc_test, list_z_train, list_z_test

# %% [markdown]
# ### Leave One Out based on ZFactor, SVM
# Computes the ZFactor shift removing one feature to the SVM classification.

# %%
XLOO = X_subset.copy()
C = best_C[0].C

CV = 3

lacc_train, lacc_test, lztrain, lztest, llfeature_removed, llacc_train, llacc_test, llz_train, llz_test = [], [], [], [], [], [], [], [], []

for crossval in range(CV):
        acc_train, acc_test, ztrain, ztest, lfeature_removed, lacc_train, lacc_test, lz_train, lz_test = LOO_features_SVM(XLOO, Y_training, train_set_proportion = 0.8, C=C, seed=crossval)
        lacc_train.append(acc_train)
        lacc_test.append(acc_test)
        lztrain.append(ztrain)
        lztest.append(ztest)
        llfeature_removed.append(lfeature_removed)
        llacc_train.append(lacc_train)
        llacc_test.append(lacc_test)
        llz_train.append(lz_train)
        llz_test.append(lz_test)


vec_cv_ztrain = []
vec_cv_ztest = []


for i, val in enumerate(lztrain):
        vec_cv_ztrain.append(-np.array(llz_train[i]) + lztrain[i])
        vec_cv_ztest.append(-np.array(llz_test[i]) + lztest[i])

df_loo_svm = pd.DataFrame()

# display(vec_cv_ztrain)

df_loo_svm['Feature'] = lfeature_removed
df_loo_svm['Diff_ZTrain'] = np.mean(vec_cv_ztrain, axis=0)
df_loo_svm['Diff_ZTest'] = np.mean(vec_cv_ztest, axis=0)
df_loo_svm['std_ZTrain'] = np.std(vec_cv_ztrain, axis=0)
df_loo_svm['std_ZTest'] = np.std(vec_cv_ztest, axis=0)

df_loo_svm.sort_values(['Diff_ZTrain'], inplace=True)

my_cmap_red = plt.get_cmap("Reds")
my_cmap_blue = plt.get_cmap("Blues")

my_colors = []
for value in df_loo_svm['Diff_ZTrain']:
        if value < 0:
                my_colors.append(my_cmap_red(.5+np.abs(0.25*value/df_loo_svm['Diff_ZTrain'].min())))
        else:
                my_colors.append(my_cmap_blue(.5+np.abs(0.25*value/df_loo_svm['Diff_ZTrain'].max())))

f, ax = plt.subplots(figsize=(10,20))

ax.barh(range(len(df_loo_svm)),
        df_loo_svm['Diff_ZTrain'],
        xerr=df_loo_svm['std_ZTest'],
        align='center', edgecolor='k', color=my_colors)

ax.set_yticks(range(len(df_loo_svm)))
ax.set_yticklabels(df_loo_svm['Feature'])
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

plt.xlabel('ZFactor Shift')
plt.title('Feature Importances : LOO ZFactor Train Set')
plt.savefig(output_path_loo+"LOO_SVM_Train_Set.pdf", bbox_inches='tight')
plt.show()

df_loo_svm.sort_values(['Diff_ZTest'], inplace=True)

my_cmap_red = plt.get_cmap("Reds")
my_cmap_blue = plt.get_cmap("Blues")

my_colors = []
for value in df_loo_svm['Diff_ZTest']:
        if value < 0:
                my_colors.append(my_cmap_red(.5+np.abs(0.25*value/df_loo_svm['Diff_ZTest'].min())))
        else:
                my_colors.append(my_cmap_blue(.5+np.abs(0.25*value/df_loo_svm['Diff_ZTest'].max())))

f, ax = plt.subplots(figsize=(2.5,5))

df_loo_svm = df_loo_svm.sort_values('Diff_ZTest')

df_loo_svm = df_loo_svm.tail(10)

ax.barh(range(len(df_loo_svm)),
        df_loo_svm['Diff_ZTest'],
        xerr=df_loo_svm['std_ZTest'],
        align='center', edgecolor='k', color='#1f77b4')

ax.set_yticks(range(len(df_loo_svm)))
ax.set_yticklabels(df_loo_svm['Feature'])
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

plt.xlabel('ZFactor Shift')
plt.title('Feature Importances : LOO ZFactor Test Set')
plt.savefig(output_path_loo+"LOO_SVM_Test_Set.pdf", bbox_inches='tight')
plt.show()
